# %%
import os
import json
import pandas as pd
import numpy as np
from PIL import Image
from torch.utils.data import Dataset
import torch

# Custom class for recieving data and transforming it
class SkinCancerDataset(Dataset):

  def __init__(self, data_dict, data_dir, transforms = None):
    self.info = pd.DataFrame(data_dict)
    self.root = data_dir
    self.transforms = transforms

  def __len__(self):
    return len(self.info)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
        idx = idx.tolist()
    img_name = os.path.join(self.root,
                            self.info.iloc[idx, 0])+".jpg"
    image = Image.open(img_name).convert("RGB")
    if self.transforms is not None:
        img_as_tensor = self.transforms(image)
    label = self.info.iloc[idx, 1]

    return (img_as_tensor, torch.tensor(int(label)))

# %%
# Connect to Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/kaggle' # Folder to download dataset into
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.11.17)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)

# %%
# !kaggle datasets download -d fanconic/skin-cancer-malignant-vs-benign
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 403, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
import zipfile

# Define the path to zip file
file_path = '/content/skin-cancer-malignant-vs-benign.zip'

# Unzip the file to a specific destination
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/kaggle')

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/kaggle/data/train/benign'
b_count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        b_count += 1
print('Benign File count:', b_count)

# folder path
dir_path = r'/content/drive/MyDrive/kaggle/data/train/malignant'
m_count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        m_count += 1
print('Malignant File count:', m_count)
# Out:
# Benign File count: 0
# Malignant File count: 1

# %%
import os

# folder path
dir_path = r'/content/drive/MyDrive/kaggle/data/test/benign'
b_count_test = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        b_count_test += 1
print('Benign File count:', b_count_test)

# folder path
dir_path = r'/content/drive/MyDrive/kaggle/data/test/malignant'
m_count_test = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        m_count_test += 1
print('Malignant File count:', m_count_test)
# Out:
# Benign File count: 0
# Malignant File count: 1

# %%
# import requests
# import zipfile
# from pathlib import Path

# # Setup path to data folder
# data_path = Path("data/")
# image_path = data_path / "skin-cancer-malignant-vs-benign"

# # If the image folder doesn't exist, download it and prepare it...
# if image_path.is_dir():
#     print(f"{image_path} directory exists.")
# else:

#     !kaggle datasets download -d fanconic/skin-cancer-malignant-vs-benign
#     print(f"Did not find {image_path} directory, creating one...")
#     image_path.mkdir(parents=True, exist_ok=True)

#     # # Download pizza, steak, sushi data
#     # with open(data_path / "skin-cancer-malignant-vs-benign.zip", "wb") as f:
#     #     f.write('skin-cancer-malignant-vs-benign.zip')

#     # Unzip pizza, steak, sushi data
#     with zipfile.ZipFile(data_path / "skin-cancer-malignant-vs-benign.zip", "r") as zip_ref:
#         print("Unzipping data...")
#         zip_ref.extractall(image_path)

# # # Unzip pizza, steak, sushi data
# # with zipfile.ZipFile(image_path / "skin-cancer-malignant-vs-benign.zip", "r") as zip_ref:
# #     print("Unzipping data...")
# #     zip_ref.extractall(image_path)

data_path = "/content/drive/MyDrive/kaggle/data"

# %%
import os
import csv
import glob

# Rename raw benign training data
os.chdir(r"/content/drive/MyDrive/kaggle/data/train/benign")
for index, oldfile in enumerate(glob.glob("*.jpg"), start=1):
    newfile = 'benign-{}.jpg'.format(index)
    os.rename (oldfile, newfile)

# Rename raw malignant training data
os.chdir(r"/content/drive/MyDrive/kaggle/data/train/malignant")
for index, oldfile in enumerate(glob.glob("*.jpg"), start=1):
    newfile = 'malignant-{}.jpg'.format(index)
    os.rename (oldfile, newfile)

# %%
import os
import csv
import glob

# Rename raw benign testing data
os.chdir(r"/content/drive/MyDrive/kaggle/data/test/benign")
for index, oldfile in enumerate(glob.glob("*.jpg"), start=1):
    newfile = 'benign-{}.jpg'.format(index)
    os.rename (oldfile, newfile)

# Rename raw malignant testing data
os.chdir(r"/content/drive/MyDrive/kaggle/data/test/malignant")
for index, oldfile in enumerate(glob.glob("*.jpg"), start=1):
    newfile = 'malignant-{}.jpg'.format(index)
    os.rename (oldfile, newfile)

# %%
os.listdir("/content/drive/MyDrive/kaggle/data/train/malignant")
# Out:
# ['malignant-1.jpg',
#  'malignant-2.jpg',
#  'malignant-3.jpg',
#  'malignant-4.jpg',
#  'malignant-5.jpg',
#  'malignant-6.jpg',
#  'malignant-7.jpg',
#  'malignant-8.jpg',
#  'malignant-9.jpg',
#  'malignant-10.jpg',
#  'malignant-11.jpg',
#  'malignant-12.jpg',
#  'malignant-13.jpg',
#  'malignant-14.jpg',
#  'malignant-15.jpg',
#  'malignant-16.jpg',
#  'malignant-17.jpg',
#  'malignant-18.jpg',
#  'malignant-19.jpg',
#  'malignant-20.jpg',
#  'malignant-21.jpg',
#  'malignant-22.jpg',
#  'malignant-23.jpg',
#  'malignant-24.jpg',
#  'malignant-25.jpg',
#  'malignant-26.jpg',
#  'malignant-27.jpg',
#  'malignant-28.jpg',
#  'malignant-29.jpg',
#  'malignant-30.jpg',
#  'malignant-31.jpg',
#  'malignant-32.jpg',
#  'malignant-33.jpg',
#  'malignant-34.jpg',
#  'malignant-35.jpg',
#  'malignant-36.jpg',
#  'malignant-37.jpg',
#  'malignant-38.jpg',
#  'malignant-39.jpg',
#  'malignant-40.jpg',
#  'malignant-41.jpg',
#  'malignant-42.jpg',
#  'malignant-43.jpg',
#  'malignant-44.jpg',
#  'malignant-45.jpg',
#  'malignant-46.jpg',
#  'malignant-47.jpg',
#  'malignant-48.jpg',
#  'malignant-49.jpg',
#  'malignant-50.jpg',
#  'malignant-51.jpg',
#  'malignant-52.jpg',
#  'malignant-53.jpg',
#  'malignant-54.jpg',
#  'malignant-55.jpg',
#  'malignant-56.jpg',
#  'malignant-57.jpg',
#  'malignant-58.jpg',
#  'malignant-59.jpg',
#  'malignant-60.jpg',
#  'malignant-61.jpg',
#  'malignant-62.jpg',
#  'malignant-63.jpg',
#  'malignant-64.jpg',
#  'malignant-65.jpg',
#  'malignant-66.jpg',
#  'malignant-67.jpg',
#  'malignant-68.jpg',
#  'malignant-69.jpg',
#  'malignant-70.jpg',
#  'malignant-71.jpg',
#  'malignant-72.jpg',
#  'malignant-73.jpg',
#  'malignant-74.jpg',
#  'malignant-75.jpg',
#  'malignant-76.jpg',
#  'malignant-77.jpg',
#  'malignant-78.jpg',
#  'malignant-79.jpg',
#  'malignant-80.jpg',
#  'malignant-81.jpg',
#  'malignant-82.jpg',
#  'malignant-83.jpg',
#  'malignant-84.jpg',
#  'malignant-85.jpg',
#  'malignant-86.jpg',
#  'malignant-87.jpg',
#  'malignant-88.jpg',
#  'malignant-89.jpg',
#  'malignant-90.jpg',
#  'malignant-91.jpg',
#  'malignant-92.jpg',
#  'malignant-93.jpg',
#  'malignant-94.jpg',
#  'malignant-95.jpg',
#  'malignant-96.jpg',
#  'malignant-97.jpg',
#  'malignant-98.jpg',
#  'malignant-99.jpg',
#  'malignant-100.jpg',
#  'malignant-101.jpg',
#  'malignant-102.jpg',
#  'malignant-103.jpg',
#  'malignant-104.jpg',
#  'malignant-105.jpg',
#  'malignant-106.jpg',
#  'malignant-107.jpg',
#  'malignant-108.jpg',
#  'malignant-109.jpg',
#  'malignant-110.jpg',
#  'malignant-111.jpg',
#  'malignant-112.jpg',
#  'malignant-113.jpg',
#  'malignant-114.jpg',
#  'malignant-115.jpg',
#  'malignant-116.jpg',
#  'malignant-117.jpg',
#  'malignant-118.jpg',
#  'malignant-119.jpg',
#  'malignant-120.jpg',
#  'malignant-121.jpg',
#  'malignant-122.jpg',
#  'malignant-123.jpg',
#  'malignant-124.jpg',
#  'malignant-125.jpg',
#  'malignant-126.jpg',
#  'malignant-127.jpg',
#  'malignant-128.jpg',
#  'malignant-129.jpg',
#  'malignant-130.jpg',
#  'malignant-131.jpg',
#  'malignant-132.jpg',
#  'malignant-133.jpg',
#  'malignant-134.jpg',
#  'malignant-135.jpg',
#  'malignant-136.jpg',
#  'malignant-137.jpg',
#  'malignant-138.jpg',
#  'malignant-139.jpg',
#  'malignant-140.jpg',
#  'malignant-141.jpg',
#  'malignant-142.jpg',
#  'malignant-143.jpg',
#  'malignant-144.jpg',
#  'malignant-145.jpg',
#  'malignant-146.jpg',
#  'malignant-147.jpg',
#  'malignant-148.jpg',
#  'malignant-149.jpg',
#  'malignant-150.jpg',
#  'malignant-151.jpg',
#  'malignant-152.jpg',
#  'malignant-153.jpg',
#  'malignant-154.jpg',
#  'malignant-155.jpg',
#  'malignant-156.jpg',
#  'malignant-157.jpg',
#  'malignant-158.jpg',
#  'malignant-159.jpg',
#  'malignant-160.jpg',
#  'malignant-161.jpg',
#  'malignant-162.jpg',
#  'malignant-163.jpg',
#  'malignant-164.jpg',
#  'malignant-165.jpg',
#  'malignant-166.jpg',
#  'malignant-167.jpg',
#  'malignant-168.jpg',
#  'malignant-169.jpg',
#  'malignant-170.jpg',
#  'malignant-171.jpg',
#  'malignant-172.jpg',
#  'malignant-173.jpg',
#  'malignant-174.jpg',
#  'malignant-175.jpg',
#  'malignant-176.jpg',
#  'malignant-177.jpg',
#  'malignant-178.jpg',
#  'malignant-179.jpg',
#  'malignant-180.jpg',
#  'malignant-181.jpg',
#  'malignant-182.jpg',
#  'malignant-183.jpg',
#  'malignant-184.jpg',
#  'malignant-185.jpg',
#  'malignant-186.jpg',
#  'malignant-187.jpg',
#  'malignant-188.jpg',
#  'malignant-189.jpg',
#  'malignant-190.jpg',
#  'malignant-191.jpg',
#  'malignant-192.jpg',
#  'malignant-193.jpg',
#  'malignant-194.jpg',
#  'malignant-195.jpg',
#  'malignant-196.jpg',
#  'malignant-197.jpg',
#  'malignant-198.jpg',
#  'malignant-199.jpg',
#  'malignant-200.jpg',
#  'malignant-201.jpg',
#  'malignant-202.jpg',
#  'malignant-203.jpg',
#  'malignant-204.jpg',
#  'malignant-205.jpg',
#  'malignant-206.jpg',
#  'malignant-207.jpg',
#  'malignant-208.jpg',
#  'malignant-209.jpg',
#  'malignant-210.jpg',
#  'malignant-211.jpg',
#  'malignant-212.jpg',
#  'malignant-213.jpg',
#  'malignant-214.jpg',
#  'malignant-215.jpg',
#  'malignant-216.jpg',
#  'malignant-217.jpg',
#  'malignant-218.jpg',
#  'malignant-219.jpg',
#  'malignant-220.jpg',
#  'malignant-221.jpg',
#  'malignant-222.jpg',
#  'malignant-223.jpg',
#  'malignant-224.jpg',
#  'malignant-225.jpg',
#  'malignant-226.jpg',
#  'malignant-227.jpg',
#  'malignant-228.jpg',
#  'malignant-229.jpg',
#  'malignant-230.jpg',
#  'malignant-231.jpg',
#  'malignant-232.jpg',
#  'malignant-233.jpg',
#  'malignant-234.jpg',
#  'malignant-235.jpg',
#  'malignant-236.jpg',
#  'malignant-237.jpg',
#  'malignant-238.jpg',
#  'malignant-239.jpg',
#  'malignant-240.jpg',
#  'malignant-241.jpg',
#  'malignant-242.jpg',
#  'malignant-243.jpg',
#  'malignant-244.jpg',
#  'malignant-245.jpg',
#  'malignant-246.jpg',
#  'malignant-247.jpg',
#  'malignant-248.jpg',
#  'malignant-249.jpg',
#  'malignant-250.jpg',
#  'malignant-251.jpg',
#  'malignant-252.jpg',
#  'malignant-253.jpg',
#  'malignant-254.jpg',
#  'malignant-255.jpg',
#  'malignant-256.jpg',
#  'malignant-257.jpg',
#  'malignant-258.jpg',
#  'malignant-259.jpg',
#  'malignant-260.jpg',
#  'malignant-261.jpg',
#  'malignant-262.jpg',
#  'malignant-263.jpg',
#  'malignant-264.jpg',
#  'malignant-265.jpg',
#  'malignant-266.jpg',
#  'malignant-267.jpg',
#  'malignant-268.jpg',
#  'malignant-269.jpg',
#  'malignant-270.jpg',
#  'malignant-271.jpg',
#  'malignant-272.jpg',
#  'malignant-273.jpg',
#  'malignant-274.jpg',
#  'malignant-275.jpg',
#  'malignant-276.jpg',
#  'malignant-277.jpg',
#  'malignant-278.jpg',
#  'malignant-279.jpg',
#  'malignant-280.jpg',
#  'malignant-281.jpg',
#  'malignant-282.jpg',
#  'malignant-283.jpg',
#  'malignant-284.jpg',
#  'malignant-285.jpg',
#  'malignant-286.jpg',
#  'malignant-287.jpg',
#  'malignant-288.jpg',
#  'malignant-289.jpg',
#  'malignant-290.jpg',
#  'malignant-291.jpg',
#  'malignant-292.jpg',
#  'malignant-293.jpg',
#  'malignant-294.jpg',
#  'malignant-295.jpg',
#  'malignant-296.jpg',
#  'malignant-297.jpg',
#  'malignant-298.jpg',
#  'malignant-299.jpg',
#  'malignant-300.jpg',
#  'malignant-301.jpg',
#  'malignant-302.jpg',
#  'malignant-303.jpg',
#  'malignant-304.jpg',
#  'malignant-305.jpg',
#  'malignant-306.jpg',
#  'malignant-307.jpg',
#  'malignant-308.jpg',
#  'malignant-309.jpg',
#  'malignant-310.jpg',
#  'malignant-311.jpg',
#  'malignant-312.jpg',
#  'malignant-313.jpg',
#  'malignant-314.jpg',
#  'malignant-315.jpg',
#  'malignant-316.jpg',
#  'malignant-317.jpg',
#  'malignant-318.jpg',
#  'malignant-319.jpg',
#  'malignant-320.jpg',
#  'malignant-321.jpg',
#  'malignant-322.jpg',
#  'malignant-323.jpg',
#  'malignant-324.jpg',
#  'malignant-325.jpg',
#  'malignant-326.jpg',
#  'malignant-327.jpg',
#  'malignant-328.jpg',
#  'malignant-329.jpg',
#  'malignant-330.jpg',
#  'malignant-331.jpg',
#  'malignant-332.jpg',
#  'malignant-333.jpg',
#  'malignant-334.jpg',
#  'malignant-335.jpg',
#  'malignant-336.jpg',
#  'malignant-337.jpg',
#  'malignant-338.jpg',
#  'malignant-339.jpg',
#  'malignant-340.jpg',
#  'malignant-341.jpg',
#  'malignant-342.jpg',
#  'malignant-343.jpg',
#  'malignant-344.jpg',
#  'malignant-345.jpg',
#  'malignant-346.jpg',
#  'malignant-347.jpg',
#  'malignant-348.jpg',
#  'malignant-349.jpg',
#  'malignant-350.jpg',
#  'malignant-351.jpg',
#  'malignant-352.jpg',
#  'malignant-353.jpg',
#  'malignant-354.jpg',
#  'malignant-355.jpg',
#  'malignant-356.jpg',
#  'malignant-357.jpg',
#  'malignant-358.jpg',
#  'malignant-359.jpg',
#  'malignant-360.jpg',
#  'malignant-361.jpg',
#  'malignant-362.jpg',
#  'malignant-363.jpg',
#  'malignant-364.jpg',
#  'malignant-365.jpg',
#  'malignant-366.jpg',
#  'malignant-367.jpg',
#  'malignant-368.jpg',
#  'malignant-369.jpg',
#  'malignant-370.jpg',
#  'malignant-371.jpg',
#  'malignant-372.jpg',
#  'malignant-373.jpg',
#  'malignant-374.jpg',
#  'malignant-375.jpg',
#  'malignant-376.jpg',
#  'malignant-377.jpg',
#  'malignant-378.jpg',
#  'malignant-379.jpg',
#  'malignant-380.jpg',
#  'malignant-381.jpg',
#  'malignant-382.jpg',
#  'malignant-383.jpg',
#  'malignant-384.jpg',
#  'malignant-385.jpg',
#  'malignant-386.jpg',
#  'malignant-387.jpg',
#  'malignant-388.jpg',
#  'malignant-389.jpg',
#  'malignant-390.jpg',
#  'malignant-391.jpg',
#  'malignant-392.jpg',
#  'malignant-393.jpg',
#  'malignant-394.jpg',
#  'malignant-395.jpg',
#  'malignant-396.jpg',
#  'malignant-397.jpg',
#  'malignant-398.jpg',
#  'malignant-399.jpg',
#  'malignant-400.jpg',
#  'malignant-401.jpg',
#  'malignant-402.jpg',
#  'malignant-403.jpg',
#  'malignant-404.jpg',
#  'malignant-405.jpg',
#  'malignant-406.jpg',
#  'malignant-407.jpg',
#  'malignant-408.jpg',
#  'malignant-409.jpg',
#  'malignant-410.jpg',
#  'malignant-411.jpg',
#  'malignant-412.jpg',
#  'malignant-413.jpg',
#  'malignant-414.jpg',
#  'malignant-415.jpg',
#  'malignant-416.jpg',
#  'malignant-417.jpg',
#  'malignant-418.jpg',
#  'malignant-419.jpg',
#  'malignant-420.jpg',
#  'malignant-421.jpg',
#  'malignant-422.jpg',
#  'malignant-423.jpg',
#  'malignant-424.jpg',
#  'malignant-425.jpg',
#  'malignant-426.jpg',
#  'malignant-427.jpg',
#  'malignant-428.jpg',
#  'malignant-429.jpg',
#  'malignant-430.jpg',
#  'malignant-431.jpg',
#  'malignant-432.jpg',
#  'malignant-433.jpg',
#  'malignant-434.jpg',
#  'malignant-435.jpg',
#  'malignant-436.jpg',
#  'malignant-437.jpg',
#  'malignant-438.jpg',
#  'malignant-439.jpg',
#  'malignant-440.jpg',
#  'malignant-441.jpg',
#  'malignant-442.jpg',
#  'malignant-443.jpg',
#  'malignant-444.jpg',
#  'malignant-445.jpg',
#  'malignant-446.jpg',
#  'malignant-447.jpg',
#  'malignant-448.jpg',
#  'malignant-449.jpg',
#  'malignant-450.jpg',
#  'malignant-451.jpg',
#  'malignant-452.jpg',
#  'malignant-453.jpg',
#  'malignant-454.jpg',
#  'malignant-455.jpg',
#  'malignant-456.jpg',
#  'malignant-457.jpg',
#  'malignant-458.jpg',
#  'malignant-459.jpg',
#  'malignant-460.jpg',
#  'malignant-461.jpg',
#  'malignant-462.jpg',
#  'malignant-463.jpg',
#  'malignant-464.jpg',
#  'malignant-465.jpg',
#  'malignant-466.jpg',
#  'malignant-467.jpg',
#  'malignant-468.jpg',
#  'malignant-469.jpg',
#  'malignant-470.jpg',
#  'malignant-471.jpg',
#  'malignant-472.jpg',
#  'malignant-473.jpg',
#  'malignant-474.jpg',
#  'malignant-475.jpg',
#  'malignant-476.jpg',
#  'malignant-477.jpg',
#  'malignant-478.jpg',
#  'malignant-479.jpg',
#  'malignant-480.jpg',
#  'malignant-481.jpg',
#  'malignant-482.jpg',
#  'malignant-483.jpg',
#  'malignant-484.jpg',
#  'malignant-485.jpg',
#  'malignant-486.jpg',
#  'malignant-487.jpg',
#  'malignant-488.jpg',
#  'malignant-489.jpg',
#  'malignant-490.jpg',
#  'malignant-491.jpg',
#  'malignant-492.jpg',
#  'malignant-493.jpg',
#  'malignant-494.jpg',
#  'malignant-495.jpg',
#  'malignant-496.jpg',
#  'malignant-497.jpg',
#  'malignant-498.jpg',
#  'malignant-499.jpg',
#  'malignant-500.jpg',
#  'malignant-501.jpg',
#  'malignant-502.jpg',
#  'malignant-503.jpg',
#  'malignant-504.jpg',
#  'malignant-505.jpg',
#  'malignant-506.jpg',
#  'malignant-507.jpg',
#  'malignant-508.jpg',
#  'malignant-509.jpg',
#  'malignant-510.jpg',
#  'malignant-511.jpg',
#  'malignant-512.jpg',
#  'malignant-513.jpg',
#  'malignant-514.jpg',
#  'malignant-515.jpg',
#  'malignant-516.jpg',
#  'malignant-517.jpg',
#  'malignant-518.jpg',
#  'malignant-519.jpg',
#  'malignant-520.jpg',
#  'malignant-521.jpg',
#  'malignant-522.jpg',
#  'malignant-523.jpg',
#  'malignant-524.jpg',
#  'malignant-525.jpg',
#  'malignant-526.jpg',
#  'malignant-527.jpg',
#  'malignant-528.jpg',
#  'malignant-529.jpg',
#  'malignant-530.jpg',
#  'malignant-531.jpg',
#  'malignant-532.jpg',
#  'malignant-533.jpg',
#  'malignant-534.jpg',
#  'malignant-535.jpg',
#  'malignant-536.jpg',
#  'malignant-537.jpg',
#  'malignant-538.jpg',
#  'malignant-539.jpg',
#  'malignant-540.jpg',
#  'malignant-541.jpg',
#  'malignant-542.jpg',
#  'malignant-543.jpg',
#  'malignant-544.jpg',
#  'malignant-545.jpg',
#  'malignant-546.jpg',
#  'malignant-547.jpg',
#  'malignant-548.jpg',
#  'malignant-549.jpg',
#  'malignant-550.jpg',
#  'malignant-551.jpg',
#  'malignant-552.jpg',
#  'malignant-553.jpg',
#  'malignant-554.jpg',
#  'malignant-555.jpg',
#  'malignant-556.jpg',
#  'malignant-557.jpg',
#  'malignant-558.jpg',
#  'malignant-559.jpg',
#  'malignant-560.jpg',
#  'malignant-561.jpg',
#  'malignant-562.jpg',
#  'malignant-563.jpg',
#  'malignant-564.jpg',
#  'malignant-565.jpg',
#  'malignant-566.jpg',
#  'malignant-567.jpg',
#  'malignant-568.jpg',
#  'malignant-569.jpg',
#  'malignant-570.jpg',
#  'malignant-571.jpg',
#  'malignant-572.jpg',
#  'malignant-573.jpg',
#  'malignant-574.jpg',
#  'malignant-575.jpg',
#  'malignant-576.jpg',
#  'malignant-577.jpg',
#  'malignant-578.jpg',
#  'malignant-579.jpg',
#  'malignant-580.jpg',
#  'malignant-581.jpg',
#  'malignant-582.jpg',
#  'malignant-583.jpg',
#  'malignant-584.jpg',
#  'malignant-585.jpg',
#  'malignant-586.jpg',
#  'malignant-587.jpg',
#  'malignant-588.jpg',
#  'malignant-589.jpg',
#  'malignant-590.jpg',
#  'malignant-591.jpg',
#  'malignant-592.jpg',
#  'malignant-593.jpg',
#  'malignant-594.jpg',
#  'malignant-595.jpg',
#  'malignant-596.jpg',
#  'malignant-597.jpg',
#  'malignant-598.jpg',
#  'malignant-599.jpg',
#  'malignant-600.jpg',
#  'malignant-601.jpg',
#  'malignant-602.jpg',
#  'malignant-603.jpg',
#  'malignant-604.jpg',
#  'malignant-605.jpg',
#  'malignant-606.jpg',
#  'malignant-607.jpg',
#  'malignant-608.jpg',
#  'malignant-609.jpg',
#  'malignant-610.jpg',
#  'malignant-611.jpg',
#  'malignant-612.jpg',
#  'malignant-613.jpg',
#  'malignant-614.jpg',
#  'malignant-615.jpg',
#  'malignant-616.jpg',
#  'malignant-617.jpg',
#  'malignant-618.jpg',
#  'malignant-619.jpg',
#  'malignant-620.jpg',
#  'malignant-621.jpg',
#  'malignant-622.jpg',
#  'malignant-623.jpg',
#  'malignant-624.jpg',
#  'malignant-625.jpg',
#  'malignant-626.jpg',
#  'malignant-627.jpg',
#  'malignant-628.jpg',
#  'malignant-629.jpg',
#  'malignant-630.jpg',
#  'malignant-631.jpg',
#  'malignant-632.jpg',
#  'malignant-633.jpg',
#  'malignant-634.jpg',
#  'malignant-635.jpg',
#  'malignant-636.jpg',
#  'malignant-637.jpg',
#  'malignant-638.jpg',
#  'malignant-639.jpg',
#  'malignant-640.jpg',
#  'malignant-641.jpg',
#  'malignant-642.jpg',
#  'malignant-643.jpg',
#  'malignant-644.jpg',
#  'malignant-645.jpg',
#  'malignant-646.jpg',
#  'malignant-647.jpg',
#  'malignant-648.jpg',
#  'malignant-649.jpg',
#  'malignant-650.jpg',
#  'malignant-651.jpg',
#  'malignant-652.jpg',
#  'malignant-653.jpg',
#  'malignant-654.jpg',
#  'malignant-655.jpg',
#  'malignant-656.jpg',
#  'malignant-657.jpg',
#  'malignant-658.jpg',
#  'malignant-659.jpg',
#  'malignant-660.jpg',
#  'malignant-661.jpg',
#  'malignant-662.jpg',
#  'malignant-663.jpg',
#  'malignant-664.jpg',
#  'malignant-665.jpg',
#  'malignant-666.jpg',
#  'malignant-667.jpg',
#  'malignant-668.jpg',
#  'malignant-669.jpg',
#  'malignant-670.jpg',
#  'malignant-671.jpg',
#  'malignant-672.jpg',
#  'malignant-673.jpg',
#  'malignant-674.jpg',
#  'malignant-675.jpg',
#  'malignant-676.jpg',
#  'malignant-677.jpg',
#  'malignant-678.jpg',
#  'malignant-679.jpg',
#  'malignant-680.jpg',
#  'malignant-681.jpg',
#  'malignant-682.jpg',
#  'malignant-683.jpg',
#  'malignant-684.jpg',
#  'malignant-685.jpg',
#  'malignant-686.jpg',
#  'malignant-687.jpg',
#  'malignant-688.jpg',
#  'malignant-689.jpg',
#  'malignant-690.jpg',
#  'malignant-691.jpg',
#  'malignant-692.jpg',
#  'malignant-693.jpg',
#  'malignant-694.jpg',
#  'malignant-695.jpg',
#  'malignant-696.jpg',
#  'malignant-697.jpg',
#  'malignant-698.jpg',
#  'malignant-699.jpg',
#  'malignant-700.jpg',
#  'malignant-701.jpg',
#  'malignant-702.jpg',
#  'malignant-703.jpg',
#  'malignant-704.jpg',
#  'malignant-705.jpg',
#  'malignant-706.jpg',
#  'malignant-707.jpg',
#  'malignant-708.jpg',
#  'malignant-709.jpg',
#  'malignant-710.jpg',
#  'malignant-711.jpg',
#  'malignant-712.jpg',
#  'malignant-713.jpg',
#  'malignant-714.jpg',
#  'malignant-715.jpg',
#  'malignant-716.jpg',
#  'malignant-717.jpg',
#  'malignant-718.jpg',
#  'malignant-719.jpg',
#  'malignant-720.jpg',
#  'malignant-721.jpg',
#  'malignant-722.jpg',
#  'malignant-723.jpg',
#  'malignant-724.jpg',
#  'malignant-725.jpg',
#  'malignant-726.jpg',
#  'malignant-727.jpg',
#  'malignant-728.jpg',
#  'malignant-729.jpg',
#  'malignant-730.jpg',
#  'malignant-731.jpg',
#  'malignant-732.jpg',
#  'malignant-733.jpg',
#  'malignant-734.jpg',
#  'malignant-735.jpg',
#  'malignant-736.jpg',
#  'malignant-737.jpg',
#  'malignant-738.jpg',
#  'malignant-739.jpg',
#  'malignant-740.jpg',
#  'malignant-741.jpg',
#  'malignant-742.jpg',
#  'malignant-743.jpg',
#  'malignant-744.jpg',
#  'malignant-745.jpg',
#  'malignant-746.jpg',
#  'malignant-747.jpg',
#  'malignant-748.jpg',
#  'malignant-749.jpg',
#  'malignant-750.jpg',
#  'malignant-751.jpg',
#  'malignant-752.jpg',
#  'malignant-753.jpg',
#  'malignant-754.jpg',
#  'malignant-755.jpg',
#  'malignant-756.jpg',
#  'malignant-757.jpg',
#  'malignant-758.jpg',
#  'malignant-759.jpg',
#  'malignant-760.jpg',
#  'malignant-761.jpg',
#  'malignant-762.jpg',
#  'malignant-763.jpg',
#  'malignant-764.jpg',
#  'malignant-765.jpg',
#  'malignant-766.jpg',
#  'malignant-767.jpg',
#  'malignant-768.jpg',
#  'malignant-769.jpg',
#  'malignant-770.jpg',
#  'malignant-771.jpg',
#  'malignant-772.jpg',
#  'malignant-773.jpg',
#  'malignant-774.jpg',
#  'malignant-775.jpg',
#  'malignant-776.jpg',
#  'malignant-777.jpg',
#  'malignant-778.jpg',
#  'malignant-779.jpg',
#  'malignant-780.jpg',
#  'malignant-781.jpg',
#  'malignant-782.jpg',
#  'malignant-783.jpg',
#  'malignant-784.jpg',
#  'malignant-785.jpg',
#  'malignant-786.jpg',
#  'malignant-787.jpg',
#  'malignant-788.jpg',
#  'malignant-789.jpg',
#  'malignant-790.jpg',
#  'malignant-791.jpg',
#  'malignant-792.jpg',
#  'malignant-793.jpg',
#  'malignant-794.jpg',
#  'malignant-795.jpg',
#  'malignant-796.jpg',
#  'malignant-797.jpg',
#  'malignant-798.jpg',
#  'malignant-799.jpg',
#  'malignant-800.jpg',
#  'malignant-801.jpg',
#  'malignant-802.jpg',
#  'malignant-803.jpg',
#  'malignant-804.jpg',
#  'malignant-805.jpg',
#  'malignant-806.jpg',
#  'malignant-807.jpg',
#  'malignant-808.jpg',
#  'malignant-809.jpg',
#  'malignant-810.jpg',
#  'malignant-811.jpg',
#  'malignant-812.jpg',
#  'malignant-813.jpg',
#  'malignant-814.jpg',
#  'malignant-815.jpg',
#  'malignant-816.jpg',
#  'malignant-817.jpg',
#  'malignant-818.jpg',
#  'malignant-819.jpg',
#  'malignant-820.jpg',
#  'malignant-821.jpg',
#  'malignant-822.jpg',
#  'malignant-823.jpg',
#  'malignant-824.jpg',
#  'malignant-825.jpg',
#  'malignant-826.jpg',
#  'malignant-827.jpg',
#  'malignant-828.jpg',
#  'malignant-829.jpg',
#  'malignant-830.jpg',
#  'malignant-831.jpg',
#  'malignant-832.jpg',
#  'malignant-833.jpg',
#  'malignant-834.jpg',
#  'malignant-835.jpg',
#  'malignant-836.jpg',
#  'malignant-837.jpg',
#  'malignant-838.jpg',
#  'malignant-839.jpg',
#  'malignant-840.jpg',
#  'malignant-841.jpg',
#  'malignant-842.jpg',
#  'malignant-843.jpg',
#  'malignant-844.jpg',
#  'malignant-845.jpg',
#  'malignant-846.jpg',
#  'malignant-847.jpg',
#  'malignant-848.jpg',
#  'malignant-849.jpg',
#  'malignant-850.jpg',
#  'malignant-851.jpg',
#  'malignant-852.jpg',
#  'malignant-853.jpg',
#  'malignant-854.jpg',
#  'malignant-855.jpg',
#  'malignant-856.jpg',
#  'malignant-857.jpg',
#  'malignant-858.jpg',
#  'malignant-859.jpg',
#  'malignant-860.jpg',
#  'malignant-861.jpg',
#  'malignant-862.jpg',
#  'malignant-863.jpg',
#  'malignant-864.jpg',
#  'malignant-865.jpg',
#  'malignant-866.jpg',
#  'malignant-867.jpg',
#  'malignant-868.jpg',
#  'malignant-869.jpg',
#  'malignant-870.jpg',
#  'malignant-871.jpg',
#  'malignant-872.jpg',
#  'malignant-873.jpg',
#  'malignant-874.jpg',
#  'malignant-875.jpg',
#  'malignant-876.jpg',
#  'malignant-877.jpg',
#  'malignant-878.jpg',
#  'malignant-879.jpg',
#  'malignant-880.jpg',
#  'malignant-881.jpg',
#  'malignant-882.jpg',
#  'malignant-883.jpg',
#  'malignant-884.jpg',
#  'malignant-885.jpg',
#  'malignant-886.jpg',
#  'malignant-887.jpg',
#  'malignant-888.jpg',
#  'malignant-889.jpg',
#  'malignant-890.jpg',
#  'malignant-891.jpg',
#  'malignant-892.jpg',
#  'malignant-893.jpg',
#  'malignant-894.jpg',
#  'malignant-895.jpg',
#  'malignant-896.jpg',
#  'malignant-897.jpg',
#  'malignant-898.jpg',
#  'malignant-899.jpg',
#  'malignant-900.jpg',
#  'malignant-901.jpg',
#  'malignant-902.jpg',
#  'malignant-903.jpg',
#  'malignant-904.jpg',
#  'malignant-905.jpg',
#  'malignant-906.jpg',
#  'malignant-907.jpg',
#  'malignant-908.jpg',
#  'malignant-909.jpg',
#  'malignant-910.jpg',
#  'malignant-911.jpg',
#  'malignant-912.jpg',
#  'malignant-913.jpg',
#  'malignant-914.jpg',
#  'malignant-915.jpg',
#  'malignant-916.jpg',
#  'malignant-917.jpg',
#  'malignant-918.jpg',
#  'malignant-919.jpg',
#  'malignant-920.jpg',
#  'malignant-921.jpg',
#  'malignant-922.jpg',
#  'malignant-923.jpg',
#  'malignant-924.jpg',
#  'malignant-925.jpg',
#  'malignant-926.jpg',
#  'malignant-927.jpg',
#  'malignant-928.jpg',
#  'malignant-929.jpg',
#  'malignant-930.jpg',
#  'malignant-931.jpg',
#  'malignant-932.jpg',
#  'malignant-933.jpg',
#  'malignant-934.jpg',
#  'malignant-935.jpg',
#  'malignant-936.jpg',
#  'malignant-937.jpg',
#  'malignant-938.jpg',
#  'malignant-939.jpg',
#  'malignant-940.jpg',
#  'malignant-941.jpg',
#  'malignant-942.jpg',
#  'malignant-943.jpg',
#  'malignant-944.jpg',
#  'malignant-945.jpg',
#  'malignant-946.jpg',
#  'malignant-947.jpg',
#  'malignant-948.jpg',
#  'malignant-949.jpg',
#  'malignant-950.jpg',
#  'malignant-951.jpg',
#  'malignant-952.jpg',
#  'malignant-953.jpg',
#  'malignant-954.jpg',
#  'malignant-955.jpg',
#  'malignant-956.jpg',
#  'malignant-957.jpg',
#  'malignant-958.jpg',
#  'malignant-959.jpg',
#  'malignant-960.jpg',
#  'malignant-961.jpg',
#  'malignant-962.jpg',
#  'malignant-963.jpg',
#  'malignant-964.jpg',
#  'malignant-965.jpg',
#  'malignant-966.jpg',
#  'malignant-967.jpg',
#  'malignant-968.jpg',
#  'malignant-969.jpg',
#  'malignant-970.jpg',
#  'malignant-971.jpg',
#  'malignant-972.jpg',
#  'malignant-973.jpg',
#  'malignant-974.jpg',
#  'malignant-975.jpg',
#  'malignant-976.jpg',
#  'malignant-977.jpg',
#  'malignant-978.jpg',
#  'malignant-979.jpg',
#  'malignant-980.jpg',
#  'malignant-981.jpg',
#  'malignant-982.jpg',
#  'malignant-983.jpg',
#  'malignant-984.jpg',
#  'malignant-985.jpg',
#  'malignant-986.jpg',
#  'malignant-987.jpg',
#  'malignant-988.jpg',
#  'malignant-989.jpg',
#  'malignant-990.jpg',
#  'malignant-991.jpg',
#  'malignant-992.jpg',
#  'malignant-993.jpg',
#  'malignant-994.jpg',
#  'malignant-995.jpg',
#  'malignant-996.jpg',
#  'malignant-997.jpg',
#  'malignant-998.jpg',
#  'malignant-999.jpg',
#  'malignant-1000.jpg',
#  ...]

# %%
os.listdir("/content/drive/MyDrive/kaggle/data/train/benign")
# Out:
# ['benign-1.jpg',
#  'benign-2.jpg',
#  'benign-3.jpg',
#  'benign-4.jpg',
#  'benign-5.jpg',
#  'benign-6.jpg',
#  'benign-7.jpg',
#  'benign-8.jpg',
#  'benign-9.jpg',
#  'benign-10.jpg',
#  'benign-11.jpg',
#  'benign-12.jpg',
#  'benign-13.jpg',
#  'benign-14.jpg',
#  'benign-15.jpg',
#  'benign-16.jpg',
#  'benign-17.jpg',
#  'benign-18.jpg',
#  'benign-19.jpg',
#  'benign-20.jpg',
#  'benign-21.jpg',
#  'benign-22.jpg',
#  'benign-23.jpg',
#  'benign-24.jpg',
#  'benign-25.jpg',
#  'benign-26.jpg',
#  'benign-27.jpg',
#  'benign-28.jpg',
#  'benign-29.jpg',
#  'benign-30.jpg',
#  'benign-31.jpg',
#  'benign-32.jpg',
#  'benign-33.jpg',
#  'benign-34.jpg',
#  'benign-35.jpg',
#  'benign-36.jpg',
#  'benign-37.jpg',
#  'benign-38.jpg',
#  'benign-39.jpg',
#  'benign-40.jpg',
#  'benign-41.jpg',
#  'benign-42.jpg',
#  'benign-43.jpg',
#  'benign-44.jpg',
#  'benign-45.jpg',
#  'benign-46.jpg',
#  'benign-47.jpg',
#  'benign-48.jpg',
#  'benign-49.jpg',
#  'benign-50.jpg',
#  'benign-51.jpg',
#  'benign-52.jpg',
#  'benign-53.jpg',
#  'benign-54.jpg',
#  'benign-55.jpg',
#  'benign-56.jpg',
#  'benign-57.jpg',
#  'benign-58.jpg',
#  'benign-59.jpg',
#  'benign-60.jpg',
#  'benign-61.jpg',
#  'benign-62.jpg',
#  'benign-63.jpg',
#  'benign-64.jpg',
#  'benign-65.jpg',
#  'benign-66.jpg',
#  'benign-67.jpg',
#  'benign-68.jpg',
#  'benign-69.jpg',
#  'benign-70.jpg',
#  'benign-71.jpg',
#  'benign-72.jpg',
#  'benign-73.jpg',
#  'benign-74.jpg',
#  'benign-75.jpg',
#  'benign-76.jpg',
#  'benign-77.jpg',
#  'benign-78.jpg',
#  'benign-79.jpg',
#  'benign-80.jpg',
#  'benign-81.jpg',
#  'benign-82.jpg',
#  'benign-83.jpg',
#  'benign-84.jpg',
#  'benign-85.jpg',
#  'benign-86.jpg',
#  'benign-87.jpg',
#  'benign-88.jpg',
#  'benign-89.jpg',
#  'benign-90.jpg',
#  'benign-91.jpg',
#  'benign-92.jpg',
#  'benign-93.jpg',
#  'benign-94.jpg',
#  'benign-95.jpg',
#  'benign-96.jpg',
#  'benign-97.jpg',
#  'benign-98.jpg',
#  'benign-99.jpg',
#  'benign-100.jpg',
#  'benign-101.jpg',
#  'benign-102.jpg',
#  'benign-103.jpg',
#  'benign-104.jpg',
#  'benign-105.jpg',
#  'benign-106.jpg',
#  'benign-107.jpg',
#  'benign-108.jpg',
#  'benign-109.jpg',
#  'benign-110.jpg',
#  'benign-111.jpg',
#  'benign-112.jpg',
#  'benign-113.jpg',
#  'benign-114.jpg',
#  'benign-115.jpg',
#  'benign-116.jpg',
#  'benign-117.jpg',
#  'benign-118.jpg',
#  'benign-119.jpg',
#  'benign-120.jpg',
#  'benign-121.jpg',
#  'benign-122.jpg',
#  'benign-123.jpg',
#  'benign-124.jpg',
#  'benign-125.jpg',
#  'benign-126.jpg',
#  'benign-127.jpg',
#  'benign-128.jpg',
#  'benign-129.jpg',
#  'benign-130.jpg',
#  'benign-131.jpg',
#  'benign-132.jpg',
#  'benign-133.jpg',
#  'benign-134.jpg',
#  'benign-135.jpg',
#  'benign-136.jpg',
#  'benign-137.jpg',
#  'benign-138.jpg',
#  'benign-139.jpg',
#  'benign-140.jpg',
#  'benign-141.jpg',
#  'benign-142.jpg',
#  'benign-143.jpg',
#  'benign-144.jpg',
#  'benign-145.jpg',
#  'benign-146.jpg',
#  'benign-147.jpg',
#  'benign-148.jpg',
#  'benign-149.jpg',
#  'benign-150.jpg',
#  'benign-151.jpg',
#  'benign-152.jpg',
#  'benign-153.jpg',
#  'benign-154.jpg',
#  'benign-155.jpg',
#  'benign-156.jpg',
#  'benign-157.jpg',
#  'benign-158.jpg',
#  'benign-159.jpg',
#  'benign-160.jpg',
#  'benign-161.jpg',
#  'benign-162.jpg',
#  'benign-163.jpg',
#  'benign-164.jpg',
#  'benign-165.jpg',
#  'benign-166.jpg',
#  'benign-167.jpg',
#  'benign-168.jpg',
#  'benign-169.jpg',
#  'benign-170.jpg',
#  'benign-171.jpg',
#  'benign-172.jpg',
#  'benign-173.jpg',
#  'benign-174.jpg',
#  'benign-175.jpg',
#  'benign-176.jpg',
#  'benign-177.jpg',
#  'benign-178.jpg',
#  'benign-179.jpg',
#  'benign-180.jpg',
#  'benign-181.jpg',
#  'benign-182.jpg',
#  'benign-183.jpg',
#  'benign-184.jpg',
#  'benign-185.jpg',
#  'benign-186.jpg',
#  'benign-187.jpg',
#  'benign-188.jpg',
#  'benign-189.jpg',
#  'benign-190.jpg',
#  'benign-191.jpg',
#  'benign-192.jpg',
#  'benign-193.jpg',
#  'benign-194.jpg',
#  'benign-195.jpg',
#  'benign-196.jpg',
#  'benign-197.jpg',
#  'benign-198.jpg',
#  'benign-199.jpg',
#  'benign-200.jpg',
#  'benign-201.jpg',
#  'benign-202.jpg',
#  'benign-203.jpg',
#  'benign-204.jpg',
#  'benign-205.jpg',
#  'benign-206.jpg',
#  'benign-207.jpg',
#  'benign-208.jpg',
#  'benign-209.jpg',
#  'benign-210.jpg',
#  'benign-211.jpg',
#  'benign-212.jpg',
#  'benign-213.jpg',
#  'benign-214.jpg',
#  'benign-215.jpg',
#  'benign-216.jpg',
#  'benign-217.jpg',
#  'benign-218.jpg',
#  'benign-219.jpg',
#  'benign-220.jpg',
#  'benign-221.jpg',
#  'benign-222.jpg',
#  'benign-223.jpg',
#  'benign-224.jpg',
#  'benign-225.jpg',
#  'benign-226.jpg',
#  'benign-227.jpg',
#  'benign-228.jpg',
#  'benign-229.jpg',
#  'benign-230.jpg',
#  'benign-231.jpg',
#  'benign-232.jpg',
#  'benign-233.jpg',
#  'benign-234.jpg',
#  'benign-235.jpg',
#  'benign-236.jpg',
#  'benign-237.jpg',
#  'benign-238.jpg',
#  'benign-239.jpg',
#  'benign-240.jpg',
#  'benign-241.jpg',
#  'benign-242.jpg',
#  'benign-243.jpg',
#  'benign-244.jpg',
#  'benign-245.jpg',
#  'benign-246.jpg',
#  'benign-247.jpg',
#  'benign-248.jpg',
#  'benign-249.jpg',
#  'benign-250.jpg',
#  'benign-251.jpg',
#  'benign-252.jpg',
#  'benign-253.jpg',
#  'benign-254.jpg',
#  'benign-255.jpg',
#  'benign-256.jpg',
#  'benign-257.jpg',
#  'benign-258.jpg',
#  'benign-259.jpg',
#  'benign-260.jpg',
#  'benign-261.jpg',
#  'benign-262.jpg',
#  'benign-263.jpg',
#  'benign-264.jpg',
#  'benign-265.jpg',
#  'benign-266.jpg',
#  'benign-267.jpg',
#  'benign-268.jpg',
#  'benign-269.jpg',
#  'benign-270.jpg',
#  'benign-271.jpg',
#  'benign-272.jpg',
#  'benign-273.jpg',
#  'benign-274.jpg',
#  'benign-275.jpg',
#  'benign-276.jpg',
#  'benign-277.jpg',
#  'benign-278.jpg',
#  'benign-279.jpg',
#  'benign-280.jpg',
#  'benign-281.jpg',
#  'benign-282.jpg',
#  'benign-283.jpg',
#  'benign-284.jpg',
#  'benign-285.jpg',
#  'benign-286.jpg',
#  'benign-287.jpg',
#  'benign-288.jpg',
#  'benign-289.jpg',
#  'benign-290.jpg',
#  'benign-291.jpg',
#  'benign-292.jpg',
#  'benign-293.jpg',
#  'benign-294.jpg',
#  'benign-295.jpg',
#  'benign-296.jpg',
#  'benign-297.jpg',
#  'benign-298.jpg',
#  'benign-299.jpg',
#  'benign-300.jpg',
#  'benign-301.jpg',
#  'benign-302.jpg',
#  'benign-303.jpg',
#  'benign-304.jpg',
#  'benign-305.jpg',
#  'benign-306.jpg',
#  'benign-307.jpg',
#  'benign-308.jpg',
#  'benign-309.jpg',
#  'benign-310.jpg',
#  'benign-311.jpg',
#  'benign-312.jpg',
#  'benign-313.jpg',
#  'benign-314.jpg',
#  'benign-315.jpg',
#  'benign-316.jpg',
#  'benign-317.jpg',
#  'benign-318.jpg',
#  'benign-319.jpg',
#  'benign-320.jpg',
#  'benign-321.jpg',
#  'benign-322.jpg',
#  'benign-323.jpg',
#  'benign-324.jpg',
#  'benign-325.jpg',
#  'benign-326.jpg',
#  'benign-327.jpg',
#  'benign-328.jpg',
#  'benign-329.jpg',
#  'benign-330.jpg',
#  'benign-331.jpg',
#  'benign-332.jpg',
#  'benign-333.jpg',
#  'benign-334.jpg',
#  'benign-335.jpg',
#  'benign-336.jpg',
#  'benign-337.jpg',
#  'benign-338.jpg',
#  'benign-339.jpg',
#  'benign-340.jpg',
#  'benign-341.jpg',
#  'benign-342.jpg',
#  'benign-343.jpg',
#  'benign-344.jpg',
#  'benign-345.jpg',
#  'benign-346.jpg',
#  'benign-347.jpg',
#  'benign-348.jpg',
#  'benign-349.jpg',
#  'benign-350.jpg',
#  'benign-351.jpg',
#  'benign-352.jpg',
#  'benign-353.jpg',
#  'benign-354.jpg',
#  'benign-355.jpg',
#  'benign-356.jpg',
#  'benign-357.jpg',
#  'benign-358.jpg',
#  'benign-359.jpg',
#  'benign-360.jpg',
#  'benign-361.jpg',
#  'benign-362.jpg',
#  'benign-363.jpg',
#  'benign-364.jpg',
#  'benign-365.jpg',
#  'benign-366.jpg',
#  'benign-367.jpg',
#  'benign-368.jpg',
#  'benign-369.jpg',
#  'benign-370.jpg',
#  'benign-371.jpg',
#  'benign-372.jpg',
#  'benign-373.jpg',
#  'benign-374.jpg',
#  'benign-375.jpg',
#  'benign-376.jpg',
#  'benign-377.jpg',
#  'benign-378.jpg',
#  'benign-379.jpg',
#  'benign-380.jpg',
#  'benign-381.jpg',
#  'benign-382.jpg',
#  'benign-383.jpg',
#  'benign-384.jpg',
#  'benign-385.jpg',
#  'benign-386.jpg',
#  'benign-387.jpg',
#  'benign-388.jpg',
#  'benign-389.jpg',
#  'benign-390.jpg',
#  'benign-391.jpg',
#  'benign-392.jpg',
#  'benign-393.jpg',
#  'benign-394.jpg',
#  'benign-395.jpg',
#  'benign-396.jpg',
#  'benign-397.jpg',
#  'benign-398.jpg',
#  'benign-399.jpg',
#  'benign-400.jpg',
#  'benign-401.jpg',
#  'benign-402.jpg',
#  'benign-403.jpg',
#  'benign-404.jpg',
#  'benign-405.jpg',
#  'benign-406.jpg',
#  'benign-407.jpg',
#  'benign-408.jpg',
#  'benign-409.jpg',
#  'benign-410.jpg',
#  'benign-411.jpg',
#  'benign-412.jpg',
#  'benign-413.jpg',
#  'benign-414.jpg',
#  'benign-415.jpg',
#  'benign-416.jpg',
#  'benign-417.jpg',
#  'benign-418.jpg',
#  'benign-419.jpg',
#  'benign-420.jpg',
#  'benign-421.jpg',
#  'benign-422.jpg',
#  'benign-423.jpg',
#  'benign-424.jpg',
#  'benign-425.jpg',
#  'benign-426.jpg',
#  'benign-427.jpg',
#  'benign-428.jpg',
#  'benign-429.jpg',
#  'benign-430.jpg',
#  'benign-431.jpg',
#  'benign-432.jpg',
#  'benign-433.jpg',
#  'benign-434.jpg',
#  'benign-435.jpg',
#  'benign-436.jpg',
#  'benign-437.jpg',
#  'benign-438.jpg',
#  'benign-439.jpg',
#  'benign-440.jpg',
#  'benign-441.jpg',
#  'benign-442.jpg',
#  'benign-443.jpg',
#  'benign-444.jpg',
#  'benign-445.jpg',
#  'benign-446.jpg',
#  'benign-447.jpg',
#  'benign-448.jpg',
#  'benign-449.jpg',
#  'benign-450.jpg',
#  'benign-451.jpg',
#  'benign-452.jpg',
#  'benign-453.jpg',
#  'benign-454.jpg',
#  'benign-455.jpg',
#  'benign-456.jpg',
#  'benign-457.jpg',
#  'benign-458.jpg',
#  'benign-459.jpg',
#  'benign-460.jpg',
#  'benign-461.jpg',
#  'benign-462.jpg',
#  'benign-463.jpg',
#  'benign-464.jpg',
#  'benign-465.jpg',
#  'benign-466.jpg',
#  'benign-467.jpg',
#  'benign-468.jpg',
#  'benign-469.jpg',
#  'benign-470.jpg',
#  'benign-471.jpg',
#  'benign-472.jpg',
#  'benign-473.jpg',
#  'benign-474.jpg',
#  'benign-475.jpg',
#  'benign-476.jpg',
#  'benign-477.jpg',
#  'benign-478.jpg',
#  'benign-479.jpg',
#  'benign-480.jpg',
#  'benign-481.jpg',
#  'benign-482.jpg',
#  'benign-483.jpg',
#  'benign-484.jpg',
#  'benign-485.jpg',
#  'benign-486.jpg',
#  'benign-487.jpg',
#  'benign-488.jpg',
#  'benign-489.jpg',
#  'benign-490.jpg',
#  'benign-491.jpg',
#  'benign-492.jpg',
#  'benign-493.jpg',
#  'benign-494.jpg',
#  'benign-495.jpg',
#  'benign-496.jpg',
#  'benign-497.jpg',
#  'benign-498.jpg',
#  'benign-499.jpg',
#  'benign-500.jpg',
#  'benign-501.jpg',
#  'benign-502.jpg',
#  'benign-503.jpg',
#  'benign-504.jpg',
#  'benign-505.jpg',
#  'benign-506.jpg',
#  'benign-507.jpg',
#  'benign-508.jpg',
#  'benign-509.jpg',
#  'benign-510.jpg',
#  'benign-511.jpg',
#  'benign-512.jpg',
#  'benign-513.jpg',
#  'benign-514.jpg',
#  'benign-515.jpg',
#  'benign-516.jpg',
#  'benign-517.jpg',
#  'benign-518.jpg',
#  'benign-519.jpg',
#  'benign-520.jpg',
#  'benign-521.jpg',
#  'benign-522.jpg',
#  'benign-523.jpg',
#  'benign-524.jpg',
#  'benign-525.jpg',
#  'benign-526.jpg',
#  'benign-527.jpg',
#  'benign-528.jpg',
#  'benign-529.jpg',
#  'benign-530.jpg',
#  'benign-531.jpg',
#  'benign-532.jpg',
#  'benign-533.jpg',
#  'benign-534.jpg',
#  'benign-535.jpg',
#  'benign-536.jpg',
#  'benign-537.jpg',
#  'benign-538.jpg',
#  'benign-539.jpg',
#  'benign-540.jpg',
#  'benign-541.jpg',
#  'benign-542.jpg',
#  'benign-543.jpg',
#  'benign-544.jpg',
#  'benign-545.jpg',
#  'benign-546.jpg',
#  'benign-547.jpg',
#  'benign-548.jpg',
#  'benign-549.jpg',
#  'benign-550.jpg',
#  'benign-551.jpg',
#  'benign-552.jpg',
#  'benign-553.jpg',
#  'benign-554.jpg',
#  'benign-555.jpg',
#  'benign-556.jpg',
#  'benign-557.jpg',
#  'benign-558.jpg',
#  'benign-559.jpg',
#  'benign-560.jpg',
#  'benign-561.jpg',
#  'benign-562.jpg',
#  'benign-563.jpg',
#  'benign-564.jpg',
#  'benign-565.jpg',
#  'benign-566.jpg',
#  'benign-567.jpg',
#  'benign-568.jpg',
#  'benign-569.jpg',
#  'benign-570.jpg',
#  'benign-571.jpg',
#  'benign-572.jpg',
#  'benign-573.jpg',
#  'benign-574.jpg',
#  'benign-575.jpg',
#  'benign-576.jpg',
#  'benign-577.jpg',
#  'benign-578.jpg',
#  'benign-579.jpg',
#  'benign-580.jpg',
#  'benign-581.jpg',
#  'benign-582.jpg',
#  'benign-583.jpg',
#  'benign-584.jpg',
#  'benign-585.jpg',
#  'benign-586.jpg',
#  'benign-587.jpg',
#  'benign-588.jpg',
#  'benign-589.jpg',
#  'benign-590.jpg',
#  'benign-591.jpg',
#  'benign-592.jpg',
#  'benign-593.jpg',
#  'benign-594.jpg',
#  'benign-595.jpg',
#  'benign-596.jpg',
#  'benign-597.jpg',
#  'benign-598.jpg',
#  'benign-599.jpg',
#  'benign-600.jpg',
#  'benign-601.jpg',
#  'benign-602.jpg',
#  'benign-603.jpg',
#  'benign-604.jpg',
#  'benign-605.jpg',
#  'benign-606.jpg',
#  'benign-607.jpg',
#  'benign-608.jpg',
#  'benign-609.jpg',
#  'benign-610.jpg',
#  'benign-611.jpg',
#  'benign-612.jpg',
#  'benign-613.jpg',
#  'benign-614.jpg',
#  'benign-615.jpg',
#  'benign-616.jpg',
#  'benign-617.jpg',
#  'benign-618.jpg',
#  'benign-619.jpg',
#  'benign-620.jpg',
#  'benign-621.jpg',
#  'benign-622.jpg',
#  'benign-623.jpg',
#  'benign-624.jpg',
#  'benign-625.jpg',
#  'benign-626.jpg',
#  'benign-627.jpg',
#  'benign-628.jpg',
#  'benign-629.jpg',
#  'benign-630.jpg',
#  'benign-631.jpg',
#  'benign-632.jpg',
#  'benign-633.jpg',
#  'benign-634.jpg',
#  'benign-635.jpg',
#  'benign-636.jpg',
#  'benign-637.jpg',
#  'benign-638.jpg',
#  'benign-639.jpg',
#  'benign-640.jpg',
#  'benign-641.jpg',
#  'benign-642.jpg',
#  'benign-643.jpg',
#  'benign-644.jpg',
#  'benign-645.jpg',
#  'benign-646.jpg',
#  'benign-647.jpg',
#  'benign-648.jpg',
#  'benign-649.jpg',
#  'benign-650.jpg',
#  'benign-651.jpg',
#  'benign-652.jpg',
#  'benign-653.jpg',
#  'benign-654.jpg',
#  'benign-655.jpg',
#  'benign-656.jpg',
#  'benign-657.jpg',
#  'benign-658.jpg',
#  'benign-659.jpg',
#  'benign-660.jpg',
#  'benign-661.jpg',
#  'benign-662.jpg',
#  'benign-663.jpg',
#  'benign-664.jpg',
#  'benign-665.jpg',
#  'benign-666.jpg',
#  'benign-667.jpg',
#  'benign-668.jpg',
#  'benign-669.jpg',
#  'benign-670.jpg',
#  'benign-671.jpg',
#  'benign-672.jpg',
#  'benign-673.jpg',
#  'benign-674.jpg',
#  'benign-675.jpg',
#  'benign-676.jpg',
#  'benign-677.jpg',
#  'benign-678.jpg',
#  'benign-679.jpg',
#  'benign-680.jpg',
#  'benign-681.jpg',
#  'benign-682.jpg',
#  'benign-683.jpg',
#  'benign-684.jpg',
#  'benign-685.jpg',
#  'benign-686.jpg',
#  'benign-687.jpg',
#  'benign-688.jpg',
#  'benign-689.jpg',
#  'benign-690.jpg',
#  'benign-691.jpg',
#  'benign-692.jpg',
#  'benign-693.jpg',
#  'benign-694.jpg',
#  'benign-695.jpg',
#  'benign-696.jpg',
#  'benign-697.jpg',
#  'benign-698.jpg',
#  'benign-699.jpg',
#  'benign-700.jpg',
#  'benign-701.jpg',
#  'benign-702.jpg',
#  'benign-703.jpg',
#  'benign-704.jpg',
#  'benign-705.jpg',
#  'benign-706.jpg',
#  'benign-707.jpg',
#  'benign-708.jpg',
#  'benign-709.jpg',
#  'benign-710.jpg',
#  'benign-711.jpg',
#  'benign-712.jpg',
#  'benign-713.jpg',
#  'benign-714.jpg',
#  'benign-715.jpg',
#  'benign-716.jpg',
#  'benign-717.jpg',
#  'benign-718.jpg',
#  'benign-719.jpg',
#  'benign-720.jpg',
#  'benign-721.jpg',
#  'benign-722.jpg',
#  'benign-723.jpg',
#  'benign-724.jpg',
#  'benign-725.jpg',
#  'benign-726.jpg',
#  'benign-727.jpg',
#  'benign-728.jpg',
#  'benign-729.jpg',
#  'benign-730.jpg',
#  'benign-731.jpg',
#  'benign-732.jpg',
#  'benign-733.jpg',
#  'benign-734.jpg',
#  'benign-735.jpg',
#  'benign-736.jpg',
#  'benign-737.jpg',
#  'benign-738.jpg',
#  'benign-739.jpg',
#  'benign-740.jpg',
#  'benign-741.jpg',
#  'benign-742.jpg',
#  'benign-743.jpg',
#  'benign-744.jpg',
#  'benign-745.jpg',
#  'benign-746.jpg',
#  'benign-747.jpg',
#  'benign-748.jpg',
#  'benign-749.jpg',
#  'benign-750.jpg',
#  'benign-751.jpg',
#  'benign-752.jpg',
#  'benign-753.jpg',
#  'benign-754.jpg',
#  'benign-755.jpg',
#  'benign-756.jpg',
#  'benign-757.jpg',
#  'benign-758.jpg',
#  'benign-759.jpg',
#  'benign-760.jpg',
#  'benign-761.jpg',
#  'benign-762.jpg',
#  'benign-763.jpg',
#  'benign-764.jpg',
#  'benign-765.jpg',
#  'benign-766.jpg',
#  'benign-767.jpg',
#  'benign-768.jpg',
#  'benign-769.jpg',
#  'benign-770.jpg',
#  'benign-771.jpg',
#  'benign-772.jpg',
#  'benign-773.jpg',
#  'benign-774.jpg',
#  'benign-775.jpg',
#  'benign-776.jpg',
#  'benign-777.jpg',
#  'benign-778.jpg',
#  'benign-779.jpg',
#  'benign-780.jpg',
#  'benign-781.jpg',
#  'benign-782.jpg',
#  'benign-783.jpg',
#  'benign-784.jpg',
#  'benign-785.jpg',
#  'benign-786.jpg',
#  'benign-787.jpg',
#  'benign-788.jpg',
#  'benign-789.jpg',
#  'benign-790.jpg',
#  'benign-791.jpg',
#  'benign-792.jpg',
#  'benign-793.jpg',
#  'benign-794.jpg',
#  'benign-795.jpg',
#  'benign-796.jpg',
#  'benign-797.jpg',
#  'benign-798.jpg',
#  'benign-799.jpg',
#  'benign-800.jpg',
#  'benign-801.jpg',
#  'benign-802.jpg',
#  'benign-803.jpg',
#  'benign-804.jpg',
#  'benign-805.jpg',
#  'benign-806.jpg',
#  'benign-807.jpg',
#  'benign-808.jpg',
#  'benign-809.jpg',
#  'benign-810.jpg',
#  'benign-811.jpg',
#  'benign-812.jpg',
#  'benign-813.jpg',
#  'benign-814.jpg',
#  'benign-815.jpg',
#  'benign-816.jpg',
#  'benign-817.jpg',
#  'benign-818.jpg',
#  'benign-819.jpg',
#  'benign-820.jpg',
#  'benign-821.jpg',
#  'benign-822.jpg',
#  'benign-823.jpg',
#  'benign-824.jpg',
#  'benign-825.jpg',
#  'benign-826.jpg',
#  'benign-827.jpg',
#  'benign-828.jpg',
#  'benign-829.jpg',
#  'benign-830.jpg',
#  'benign-831.jpg',
#  'benign-832.jpg',
#  'benign-833.jpg',
#  'benign-834.jpg',
#  'benign-835.jpg',
#  'benign-836.jpg',
#  'benign-837.jpg',
#  'benign-838.jpg',
#  'benign-839.jpg',
#  'benign-840.jpg',
#  'benign-841.jpg',
#  'benign-842.jpg',
#  'benign-843.jpg',
#  'benign-844.jpg',
#  'benign-845.jpg',
#  'benign-846.jpg',
#  'benign-847.jpg',
#  'benign-848.jpg',
#  'benign-849.jpg',
#  'benign-850.jpg',
#  'benign-851.jpg',
#  'benign-852.jpg',
#  'benign-853.jpg',
#  'benign-854.jpg',
#  'benign-855.jpg',
#  'benign-856.jpg',
#  'benign-857.jpg',
#  'benign-858.jpg',
#  'benign-859.jpg',
#  'benign-860.jpg',
#  'benign-861.jpg',
#  'benign-862.jpg',
#  'benign-863.jpg',
#  'benign-864.jpg',
#  'benign-865.jpg',
#  'benign-866.jpg',
#  'benign-867.jpg',
#  'benign-868.jpg',
#  'benign-869.jpg',
#  'benign-870.jpg',
#  'benign-871.jpg',
#  'benign-872.jpg',
#  'benign-873.jpg',
#  'benign-874.jpg',
#  'benign-875.jpg',
#  'benign-876.jpg',
#  'benign-877.jpg',
#  'benign-878.jpg',
#  'benign-879.jpg',
#  'benign-880.jpg',
#  'benign-881.jpg',
#  'benign-882.jpg',
#  'benign-883.jpg',
#  'benign-884.jpg',
#  'benign-885.jpg',
#  'benign-886.jpg',
#  'benign-887.jpg',
#  'benign-888.jpg',
#  'benign-889.jpg',
#  'benign-890.jpg',
#  'benign-891.jpg',
#  'benign-892.jpg',
#  'benign-893.jpg',
#  'benign-894.jpg',
#  'benign-895.jpg',
#  'benign-896.jpg',
#  'benign-897.jpg',
#  'benign-898.jpg',
#  'benign-899.jpg',
#  'benign-900.jpg',
#  'benign-901.jpg',
#  'benign-902.jpg',
#  'benign-903.jpg',
#  'benign-904.jpg',
#  'benign-905.jpg',
#  'benign-906.jpg',
#  'benign-907.jpg',
#  'benign-908.jpg',
#  'benign-909.jpg',
#  'benign-910.jpg',
#  'benign-911.jpg',
#  'benign-912.jpg',
#  'benign-913.jpg',
#  'benign-914.jpg',
#  'benign-915.jpg',
#  'benign-916.jpg',
#  'benign-917.jpg',
#  'benign-918.jpg',
#  'benign-919.jpg',
#  'benign-920.jpg',
#  'benign-921.jpg',
#  'benign-922.jpg',
#  'benign-923.jpg',
#  'benign-924.jpg',
#  'benign-925.jpg',
#  'benign-926.jpg',
#  'benign-927.jpg',
#  'benign-928.jpg',
#  'benign-929.jpg',
#  'benign-930.jpg',
#  'benign-931.jpg',
#  'benign-932.jpg',
#  'benign-933.jpg',
#  'benign-934.jpg',
#  'benign-935.jpg',
#  'benign-936.jpg',
#  'benign-937.jpg',
#  'benign-938.jpg',
#  'benign-939.jpg',
#  'benign-940.jpg',
#  'benign-941.jpg',
#  'benign-942.jpg',
#  'benign-943.jpg',
#  'benign-944.jpg',
#  'benign-945.jpg',
#  'benign-946.jpg',
#  'benign-947.jpg',
#  'benign-948.jpg',
#  'benign-949.jpg',
#  'benign-950.jpg',
#  'benign-951.jpg',
#  'benign-952.jpg',
#  'benign-953.jpg',
#  'benign-954.jpg',
#  'benign-955.jpg',
#  'benign-956.jpg',
#  'benign-957.jpg',
#  'benign-958.jpg',
#  'benign-959.jpg',
#  'benign-960.jpg',
#  'benign-961.jpg',
#  'benign-962.jpg',
#  'benign-963.jpg',
#  'benign-964.jpg',
#  'benign-965.jpg',
#  'benign-966.jpg',
#  'benign-967.jpg',
#  'benign-968.jpg',
#  'benign-969.jpg',
#  'benign-970.jpg',
#  'benign-971.jpg',
#  'benign-972.jpg',
#  'benign-973.jpg',
#  'benign-974.jpg',
#  'benign-975.jpg',
#  'benign-976.jpg',
#  'benign-977.jpg',
#  'benign-978.jpg',
#  'benign-979.jpg',
#  'benign-980.jpg',
#  'benign-981.jpg',
#  'benign-982.jpg',
#  'benign-983.jpg',
#  'benign-984.jpg',
#  'benign-985.jpg',
#  'benign-986.jpg',
#  'benign-987.jpg',
#  'benign-988.jpg',
#  'benign-989.jpg',
#  'benign-990.jpg',
#  'benign-991.jpg',
#  'benign-992.jpg',
#  'benign-993.jpg',
#  'benign-994.jpg',
#  'benign-995.jpg',
#  'benign-996.jpg',
#  'benign-997.jpg',
#  'benign-998.jpg',
#  'benign-999.jpg',
#  'benign-1000.jpg',
#  ...]

# %%
os.listdir("/content/drive/MyDrive/kaggle/data/test/malignant")
# Out:
# ['malignant-1.jpg',
#  'malignant-2.jpg',
#  'malignant-3.jpg',
#  'malignant-4.jpg',
#  'malignant-5.jpg',
#  'malignant-6.jpg',
#  'malignant-7.jpg',
#  'malignant-8.jpg',
#  'malignant-9.jpg',
#  'malignant-10.jpg',
#  'malignant-11.jpg',
#  'malignant-12.jpg',
#  'malignant-13.jpg',
#  'malignant-14.jpg',
#  'malignant-15.jpg',
#  'malignant-16.jpg',
#  'malignant-17.jpg',
#  'malignant-18.jpg',
#  'malignant-19.jpg',
#  'malignant-20.jpg',
#  'malignant-21.jpg',
#  'malignant-22.jpg',
#  'malignant-23.jpg',
#  'malignant-24.jpg',
#  'malignant-25.jpg',
#  'malignant-26.jpg',
#  'malignant-27.jpg',
#  'malignant-28.jpg',
#  'malignant-29.jpg',
#  'malignant-30.jpg',
#  'malignant-31.jpg',
#  'malignant-32.jpg',
#  'malignant-33.jpg',
#  'malignant-34.jpg',
#  'malignant-35.jpg',
#  'malignant-36.jpg',
#  'malignant-37.jpg',
#  'malignant-38.jpg',
#  'malignant-39.jpg',
#  'malignant-40.jpg',
#  'malignant-41.jpg',
#  'malignant-42.jpg',
#  'malignant-43.jpg',
#  'malignant-44.jpg',
#  'malignant-45.jpg',
#  'malignant-46.jpg',
#  'malignant-47.jpg',
#  'malignant-48.jpg',
#  'malignant-49.jpg',
#  'malignant-50.jpg',
#  'malignant-51.jpg',
#  'malignant-52.jpg',
#  'malignant-53.jpg',
#  'malignant-54.jpg',
#  'malignant-55.jpg',
#  'malignant-56.jpg',
#  'malignant-57.jpg',
#  'malignant-58.jpg',
#  'malignant-59.jpg',
#  'malignant-60.jpg',
#  'malignant-61.jpg',
#  'malignant-62.jpg',
#  'malignant-63.jpg',
#  'malignant-64.jpg',
#  'malignant-65.jpg',
#  'malignant-66.jpg',
#  'malignant-67.jpg',
#  'malignant-68.jpg',
#  'malignant-69.jpg',
#  'malignant-70.jpg',
#  'malignant-71.jpg',
#  'malignant-72.jpg',
#  'malignant-73.jpg',
#  'malignant-74.jpg',
#  'malignant-75.jpg',
#  'malignant-76.jpg',
#  'malignant-77.jpg',
#  'malignant-78.jpg',
#  'malignant-79.jpg',
#  'malignant-80.jpg',
#  'malignant-81.jpg',
#  'malignant-82.jpg',
#  'malignant-83.jpg',
#  'malignant-84.jpg',
#  'malignant-85.jpg',
#  'malignant-86.jpg',
#  'malignant-87.jpg',
#  'malignant-88.jpg',
#  'malignant-89.jpg',
#  'malignant-90.jpg',
#  'malignant-91.jpg',
#  'malignant-92.jpg',
#  'malignant-93.jpg',
#  'malignant-94.jpg',
#  'malignant-95.jpg',
#  'malignant-96.jpg',
#  'malignant-97.jpg',
#  'malignant-98.jpg',
#  'malignant-99.jpg',
#  'malignant-100.jpg',
#  'malignant-101.jpg',
#  'malignant-102.jpg',
#  'malignant-103.jpg',
#  'malignant-104.jpg',
#  'malignant-105.jpg',
#  'malignant-106.jpg',
#  'malignant-107.jpg',
#  'malignant-108.jpg',
#  'malignant-109.jpg',
#  'malignant-110.jpg',
#  'malignant-111.jpg',
#  'malignant-112.jpg',
#  'malignant-113.jpg',
#  'malignant-114.jpg',
#  'malignant-115.jpg',
#  'malignant-116.jpg',
#  'malignant-117.jpg',
#  'malignant-118.jpg',
#  'malignant-119.jpg',
#  'malignant-120.jpg',
#  'malignant-121.jpg',
#  'malignant-122.jpg',
#  'malignant-123.jpg',
#  'malignant-124.jpg',
#  'malignant-125.jpg',
#  'malignant-126.jpg',
#  'malignant-127.jpg',
#  'malignant-128.jpg',
#  'malignant-129.jpg',
#  'malignant-130.jpg',
#  'malignant-131.jpg',
#  'malignant-132.jpg',
#  'malignant-133.jpg',
#  'malignant-134.jpg',
#  'malignant-135.jpg',
#  'malignant-136.jpg',
#  'malignant-137.jpg',
#  'malignant-138.jpg',
#  'malignant-139.jpg',
#  'malignant-140.jpg',
#  'malignant-141.jpg',
#  'malignant-142.jpg',
#  'malignant-143.jpg',
#  'malignant-144.jpg',
#  'malignant-145.jpg',
#  'malignant-146.jpg',
#  'malignant-147.jpg',
#  'malignant-148.jpg',
#  'malignant-149.jpg',
#  'malignant-150.jpg',
#  'malignant-151.jpg',
#  'malignant-152.jpg',
#  'malignant-153.jpg',
#  'malignant-154.jpg',
#  'malignant-155.jpg',
#  'malignant-156.jpg',
#  'malignant-157.jpg',
#  'malignant-158.jpg',
#  'malignant-159.jpg',
#  'malignant-160.jpg',
#  'malignant-161.jpg',
#  'malignant-162.jpg',
#  'malignant-163.jpg',
#  'malignant-164.jpg',
#  'malignant-165.jpg',
#  'malignant-166.jpg',
#  'malignant-167.jpg',
#  'malignant-168.jpg',
#  'malignant-169.jpg',
#  'malignant-170.jpg',
#  'malignant-171.jpg',
#  'malignant-172.jpg',
#  'malignant-173.jpg',
#  'malignant-174.jpg',
#  'malignant-175.jpg',
#  'malignant-176.jpg',
#  'malignant-177.jpg',
#  'malignant-178.jpg',
#  'malignant-179.jpg',
#  'malignant-180.jpg',
#  'malignant-181.jpg',
#  'malignant-182.jpg',
#  'malignant-183.jpg',
#  'malignant-184.jpg',
#  'malignant-185.jpg',
#  'malignant-186.jpg',
#  'malignant-187.jpg',
#  'malignant-188.jpg',
#  'malignant-189.jpg',
#  'malignant-190.jpg',
#  'malignant-191.jpg',
#  'malignant-192.jpg',
#  'malignant-193.jpg',
#  'malignant-194.jpg',
#  'malignant-195.jpg',
#  'malignant-196.jpg',
#  'malignant-197.jpg',
#  'malignant-198.jpg',
#  'malignant-199.jpg',
#  'malignant-200.jpg',
#  'malignant-201.jpg',
#  'malignant-202.jpg',
#  'malignant-203.jpg',
#  'malignant-204.jpg',
#  'malignant-205.jpg',
#  'malignant-206.jpg',
#  'malignant-207.jpg',
#  'malignant-208.jpg',
#  'malignant-209.jpg',
#  'malignant-210.jpg',
#  'malignant-211.jpg',
#  'malignant-212.jpg',
#  'malignant-213.jpg',
#  'malignant-214.jpg',
#  'malignant-215.jpg',
#  'malignant-216.jpg',
#  'malignant-217.jpg',
#  'malignant-218.jpg',
#  'malignant-219.jpg',
#  'malignant-220.jpg',
#  'malignant-221.jpg',
#  'malignant-222.jpg',
#  'malignant-223.jpg',
#  'malignant-224.jpg',
#  'malignant-225.jpg',
#  'malignant-226.jpg',
#  'malignant-227.jpg',
#  'malignant-228.jpg',
#  'malignant-229.jpg',
#  'malignant-230.jpg',
#  'malignant-231.jpg',
#  'malignant-232.jpg',
#  'malignant-233.jpg',
#  'malignant-234.jpg',
#  'malignant-235.jpg',
#  'malignant-236.jpg',
#  'malignant-237.jpg',
#  'malignant-238.jpg',
#  'malignant-239.jpg',
#  'malignant-240.jpg',
#  'malignant-241.jpg',
#  'malignant-242.jpg',
#  'malignant-243.jpg',
#  'malignant-244.jpg',
#  'malignant-245.jpg',
#  'malignant-246.jpg',
#  'malignant-247.jpg',
#  'malignant-248.jpg',
#  'malignant-249.jpg',
#  'malignant-250.jpg',
#  'malignant-251.jpg',
#  'malignant-252.jpg',
#  'malignant-253.jpg',
#  'malignant-254.jpg',
#  'malignant-255.jpg',
#  'malignant-256.jpg',
#  'malignant-257.jpg',
#  'malignant-258.jpg',
#  'malignant-259.jpg',
#  'malignant-260.jpg',
#  'malignant-261.jpg',
#  'malignant-262.jpg',
#  'malignant-263.jpg',
#  'malignant-264.jpg',
#  'malignant-265.jpg',
#  'malignant-266.jpg',
#  'malignant-267.jpg',
#  'malignant-268.jpg',
#  'malignant-269.jpg',
#  'malignant-270.jpg',
#  'malignant-271.jpg',
#  'malignant-272.jpg',
#  'malignant-273.jpg',
#  'malignant-274.jpg',
#  'malignant-275.jpg',
#  'malignant-276.jpg',
#  'malignant-277.jpg',
#  'malignant-278.jpg',
#  'malignant-279.jpg',
#  'malignant-280.jpg',
#  'malignant-281.jpg',
#  'malignant-282.jpg',
#  'malignant-283.jpg',
#  'malignant-284.jpg',
#  'malignant-285.jpg',
#  'malignant-286.jpg',
#  'malignant-287.jpg',
#  'malignant-288.jpg',
#  'malignant-289.jpg',
#  'malignant-290.jpg',
#  'malignant-291.jpg',
#  'malignant-292.jpg',
#  'malignant-293.jpg',
#  'malignant-294.jpg',
#  'malignant-295.jpg',
#  'malignant-296.jpg',
#  'malignant-297.jpg',
#  'malignant-298.jpg',
#  'malignant-299.jpg',
#  'malignant-300.jpg']

# %%
labels = {} # Labels for training images
for r in range(1, b_count + 1):
    labels["benign-{}".format(r)] = "0"

# %%
for r in range(1, m_count + 1):
    labels["malignant-{}".format(r)] = "1"

# %%
labels_test = {} # Labels for testing images
for r in range(1, b_count_test + 1):
    labels_test["benign-{}".format(r)] = "0"

# %%
for r in range(1, m_count_test + 1):
    labels_test["malignant-{}".format(r)] = "1"

# %%
labels["benign-1440"]
# Out:
# '0'

# %%
labels["malignant-1"]
# Out:
# '1'

# %%
import json

with open('labels.json', 'w') as f:
    json.dump(labels, f) # Dump dictionary into training_labels file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a3f97eb96c5f> in <cell line: 3>()
#       2
#       3 with open('labels.json', 'w') as f:
# ----> 4     json.dump(labels, f)
#
# NameError: name 'labels' is not defined

# %%
import json

with open("/content/drive/MyDrive/kaggle/c_data_test/labels_test.json", "w") as f:
  json.dump(labels_test, f) # Dump dictionary into testing_labels_file

# %%
with open('/content/drive/MyDrive/kaggle/c_data/labels.json') as f:
    targets = json.load(f)
# targets

# %%
with open('/content/drive/MyDrive/kaggle/c_data_test/labels_test.json') as f:
    targets = json.load(f)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

## Defining the NN architecture

# Load the pretrained VGG16 architechture from pytorch
vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

penultimate_layer = nn.Linear(4096, 512)
last_layer = nn.Linear(512, 2) # Last layer only 0 or 1

#Changing layers
vgg16.classifier[3] = penultimate_layer
vgg16.classifier[6] = last_layer
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:06<00:00, 79.2MB/s]

# %%
import numpy as np
import json
import torch.utils.data
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import DataLoader

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# test_size = 0.1

# %%
import os

# Directory
directory = "c_data"

# Parent Directory path
parent_dir = "/content/drive/MyDrive/kaggle"

# Path
path = os.path.join(parent_dir, directory)

# Create the directory
os.mkdir(path)
print("Directory '% s' created" % directory)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-b257a72bc2e0> in <cell line: 15>()
#      13 # 'GeeksForGeeks' in
#      14 # '/home / User / Documents'
# ---> 15 os.mkdir(path)
#      16 print("Directory '% s' created" % directory)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/kaggle/c_data'

# %%
import os

# Directory
directory = "c_data_test"

# Parent Directory path
parent_dir = "/content/drive/MyDrive/kaggle"

# Path
path = os.path.join(parent_dir, directory)

# Create the directory
# 'GeeksForGeeks' in
# '/home / User / Documents'
os.mkdir(path)
print("Directory '% s' created" % directory)
# Out:
# Directory 'c_data_test' created

# %%
os.listdir("/content/drive/MyDrive/kaggle/c_data_test")
# Out:
# []

# %%
import os
import shutil

# Moving being and malignant training images into one file for ease of access

source_folder = r"/content/drive/MyDrive/kaggle/data/train/benign/"
destination_folder = r"/content/drive/MyDrive/kaggle/c_data/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # move only files
    if os.path.isfile(source):
        shutil.move(source, destination)
        print('Moved:', file_name)

source_folder = r"/content/drive/MyDrive/kaggle/data/train/malignant/"
destination_folder = r"/content/drive/MyDrive/kaggle/c_data/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # move only files
    if os.path.isfile(source):
        shutil.move(source, destination)
        print('Moved:', file_name)
# Out:
# Moved: benign-1.jpg
# Moved: benign-2.jpg
# Moved: benign-3.jpg
# Moved: benign-4.jpg
# Moved: benign-5.jpg
# Moved: benign-6.jpg
# Moved: benign-7.jpg
# Moved: benign-8.jpg
# Moved: benign-9.jpg
# Moved: benign-10.jpg
# Moved: benign-11.jpg
# Moved: benign-12.jpg
# Moved: benign-13.jpg
# Moved: benign-14.jpg
# Moved: benign-15.jpg
# Moved: benign-16.jpg
# Moved: benign-17.jpg
# Moved: benign-18.jpg
# Moved: benign-19.jpg
# Moved: benign-20.jpg
# Moved: benign-21.jpg
# Moved: benign-22.jpg
# Moved: benign-23.jpg
# Moved: benign-24.jpg
# Moved: benign-25.jpg
# Moved: benign-26.jpg
# Moved: benign-27.jpg
# Moved: benign-28.jpg
# Moved: benign-29.jpg
# Moved: benign-30.jpg
# Moved: benign-31.jpg
# Moved: benign-32.jpg
# Moved: benign-33.jpg
# Moved: benign-34.jpg
# Moved: benign-35.jpg
# Moved: benign-36.jpg
# Moved: benign-37.jpg
# Moved: benign-38.jpg
# Moved: benign-39.jpg
# Moved: benign-40.jpg
# Moved: benign-41.jpg
# Moved: benign-42.jpg
# Moved: benign-43.jpg
# Moved: benign-44.jpg
# Moved: benign-45.jpg
# Moved: benign-46.jpg
# Moved: benign-47.jpg
# Moved: benign-48.jpg
# Moved: benign-49.jpg
# Moved: benign-50.jpg
# Moved: benign-51.jpg
# Moved: benign-52.jpg
# Moved: benign-53.jpg
# Moved: benign-54.jpg
# Moved: benign-55.jpg
# Moved: benign-56.jpg
# Moved: benign-57.jpg
# Moved: benign-58.jpg
# Moved: benign-59.jpg
# Moved: benign-60.jpg
# Moved: benign-61.jpg
# Moved: benign-62.jpg
# Moved: benign-63.jpg
# Moved: benign-64.jpg
# Moved: benign-65.jpg
# Moved: benign-66.jpg
# Moved: benign-67.jpg
# Moved: benign-68.jpg
# Moved: benign-69.jpg
# Moved: benign-70.jpg
# Moved: benign-71.jpg
# Moved: benign-72.jpg
# Moved: benign-73.jpg
# Moved: benign-74.jpg
# Moved: benign-75.jpg
# Moved: benign-76.jpg
# Moved: benign-77.jpg
# Moved: benign-78.jpg
# Moved: benign-79.jpg
# Moved: benign-80.jpg
# Moved: benign-81.jpg
# Moved: benign-82.jpg
# Moved: benign-83.jpg
# Moved: benign-84.jpg
# Moved: benign-85.jpg
# Moved: benign-86.jpg
# Moved: benign-87.jpg
# Moved: benign-88.jpg
# Moved: benign-89.jpg
# Moved: benign-90.jpg
# Moved: benign-91.jpg
# Moved: benign-92.jpg
# Moved: benign-93.jpg
# Moved: benign-94.jpg
# Moved: benign-95.jpg
# Moved: benign-96.jpg
# Moved: benign-97.jpg
# Moved: benign-98.jpg
# Moved: benign-99.jpg
# Moved: benign-100.jpg
# Moved: benign-101.jpg
# Moved: benign-102.jpg
# Moved: benign-103.jpg
# Moved: benign-104.jpg
# Moved: benign-105.jpg
# Moved: benign-106.jpg
# Moved: benign-107.jpg
# Moved: benign-108.jpg
# Moved: benign-109.jpg
# Moved: benign-110.jpg
# Moved: benign-111.jpg
# Moved: benign-112.jpg
# Moved: benign-113.jpg
# Moved: benign-114.jpg
# Moved: benign-115.jpg
# Moved: benign-116.jpg
# Moved: benign-117.jpg
# Moved: benign-118.jpg
# Moved: benign-119.jpg
# Moved: benign-120.jpg
# Moved: benign-121.jpg
# Moved: benign-122.jpg
# Moved: benign-123.jpg
# Moved: benign-124.jpg
# Moved: benign-125.jpg
# Moved: benign-126.jpg
# Moved: benign-127.jpg
# Moved: benign-128.jpg
# Moved: benign-129.jpg
# Moved: benign-130.jpg
# Moved: benign-131.jpg
# Moved: benign-132.jpg
# Moved: benign-133.jpg
# Moved: benign-134.jpg
# Moved: benign-135.jpg
# Moved: benign-136.jpg
# Moved: benign-137.jpg
# Moved: benign-138.jpg
# Moved: benign-139.jpg
# Moved: benign-140.jpg
# Moved: benign-141.jpg
# Moved: benign-142.jpg
# Moved: benign-143.jpg
# Moved: benign-144.jpg
# Moved: benign-145.jpg
# Moved: benign-146.jpg
# Moved: benign-147.jpg
# Moved: benign-148.jpg
# Moved: benign-149.jpg
# Moved: benign-150.jpg
# Moved: benign-151.jpg
# Moved: benign-152.jpg
# Moved: benign-153.jpg
# Moved: benign-154.jpg
# Moved: benign-155.jpg
# Moved: benign-156.jpg
# Moved: benign-157.jpg
# Moved: benign-158.jpg
# Moved: benign-159.jpg
# Moved: benign-160.jpg
# Moved: benign-161.jpg
# Moved: benign-162.jpg
# Moved: benign-163.jpg
# Moved: benign-164.jpg
# Moved: benign-165.jpg
# Moved: benign-166.jpg
# Moved: benign-167.jpg
# Moved: benign-168.jpg
# Moved: benign-169.jpg
# Moved: benign-170.jpg
# Moved: benign-171.jpg
# Moved: benign-172.jpg
# Moved: benign-173.jpg
# Moved: benign-174.jpg
# Moved: benign-175.jpg
# Moved: benign-176.jpg
# Moved: benign-177.jpg
# Moved: benign-178.jpg
# Moved: benign-179.jpg
# Moved: benign-180.jpg
# Moved: benign-181.jpg
# Moved: benign-182.jpg
# Moved: benign-183.jpg
# Moved: benign-184.jpg
# Moved: benign-185.jpg
# Moved: benign-186.jpg
# Moved: benign-187.jpg
# Moved: benign-188.jpg
# Moved: benign-189.jpg
# Moved: benign-190.jpg
# Moved: benign-191.jpg
# Moved: benign-192.jpg
# Moved: benign-193.jpg
# Moved: benign-194.jpg
# Moved: benign-195.jpg
# Moved: benign-196.jpg
# Moved: benign-197.jpg
# Moved: benign-198.jpg
# Moved: benign-199.jpg
# Moved: benign-200.jpg
# Moved: benign-201.jpg
# Moved: benign-202.jpg
# Moved: benign-203.jpg
# Moved: benign-204.jpg
# Moved: benign-205.jpg
# Moved: benign-206.jpg
# Moved: benign-207.jpg
# Moved: benign-208.jpg
# Moved: benign-209.jpg
# Moved: benign-210.jpg
# Moved: benign-211.jpg
# Moved: benign-212.jpg
# Moved: benign-213.jpg
# Moved: benign-214.jpg
# Moved: benign-215.jpg
# Moved: benign-216.jpg
# Moved: benign-217.jpg
# Moved: benign-218.jpg
# Moved: benign-219.jpg
# Moved: benign-220.jpg
# Moved: benign-221.jpg
# Moved: benign-222.jpg
# Moved: benign-223.jpg
# Moved: benign-224.jpg
# Moved: benign-225.jpg
# Moved: benign-226.jpg
# Moved: benign-227.jpg
# Moved: benign-228.jpg
# Moved: benign-229.jpg
# Moved: benign-230.jpg
# Moved: benign-231.jpg
# Moved: benign-232.jpg
# Moved: benign-233.jpg
# Moved: benign-234.jpg
# Moved: benign-235.jpg
# Moved: benign-236.jpg
# Moved: benign-237.jpg
# Moved: benign-238.jpg
# Moved: benign-239.jpg
# Moved: benign-240.jpg
# Moved: benign-241.jpg
# Moved: benign-242.jpg
# Moved: benign-243.jpg
# Moved: benign-244.jpg
# Moved: benign-245.jpg
# Moved: benign-246.jpg
# Moved: benign-247.jpg
# Moved: benign-248.jpg
# Moved: benign-249.jpg
# Moved: benign-250.jpg
# Moved: benign-251.jpg
# Moved: benign-252.jpg
# Moved: benign-253.jpg
# Moved: benign-254.jpg
# Moved: benign-255.jpg
# Moved: benign-256.jpg
# Moved: benign-257.jpg
# Moved: benign-258.jpg
# Moved: benign-259.jpg
# Moved: benign-260.jpg
# Moved: benign-261.jpg
# Moved: benign-262.jpg
# Moved: benign-263.jpg
# Moved: benign-264.jpg
# Moved: benign-265.jpg
# Moved: benign-266.jpg
# Moved: benign-267.jpg
# Moved: benign-268.jpg
# Moved: benign-269.jpg
# Moved: benign-270.jpg
# Moved: benign-271.jpg
# Moved: benign-272.jpg
# Moved: benign-273.jpg
# Moved: benign-274.jpg
# Moved: benign-275.jpg
# Moved: benign-276.jpg
# Moved: benign-277.jpg
# Moved: benign-278.jpg
# Moved: benign-279.jpg
# Moved: benign-280.jpg
# Moved: benign-281.jpg
# Moved: benign-282.jpg
# Moved: benign-283.jpg
# Moved: benign-284.jpg
# Moved: benign-285.jpg
# Moved: benign-286.jpg
# Moved: benign-287.jpg
# Moved: benign-288.jpg
# Moved: benign-289.jpg
# Moved: benign-290.jpg
# Moved: benign-291.jpg
# Moved: benign-292.jpg
# Moved: benign-293.jpg
# Moved: benign-294.jpg
# Moved: benign-295.jpg
# Moved: benign-296.jpg
# Moved: benign-297.jpg
# Moved: benign-298.jpg
# Moved: benign-299.jpg
# Moved: benign-300.jpg
# Moved: benign-301.jpg
# Moved: benign-302.jpg
# Moved: benign-303.jpg
# Moved: benign-304.jpg
# Moved: benign-305.jpg
# Moved: benign-306.jpg
# Moved: benign-307.jpg
# Moved: benign-308.jpg
# Moved: benign-309.jpg
# Moved: benign-310.jpg
# Moved: benign-311.jpg
# Moved: benign-312.jpg
# Moved: benign-313.jpg
# Moved: benign-314.jpg
# Moved: benign-315.jpg
# Moved: benign-316.jpg
# Moved: benign-317.jpg
# Moved: benign-318.jpg
# Moved: benign-319.jpg
# Moved: benign-320.jpg
# Moved: benign-321.jpg
# Moved: benign-322.jpg
# Moved: benign-323.jpg
# Moved: benign-324.jpg
# Moved: benign-325.jpg
# Moved: benign-326.jpg
# Moved: benign-327.jpg
# Moved: benign-328.jpg
# Moved: benign-329.jpg
# Moved: benign-330.jpg
# Moved: benign-331.jpg
# Moved: benign-332.jpg
# Moved: benign-333.jpg
# Moved: benign-334.jpg
# Moved: benign-335.jpg
# Moved: benign-336.jpg
# Moved: benign-337.jpg
# Moved: benign-338.jpg
# Moved: benign-339.jpg
# Moved: benign-340.jpg
# Moved: benign-341.jpg
# Moved: benign-342.jpg
# Moved: benign-343.jpg
# Moved: benign-344.jpg
# Moved: benign-345.jpg
# Moved: benign-346.jpg
# Moved: benign-347.jpg
# Moved: benign-348.jpg
# Moved: benign-349.jpg
# Moved: benign-350.jpg
# Moved: benign-351.jpg
# Moved: benign-352.jpg
# Moved: benign-353.jpg
# Moved: benign-354.jpg
# Moved: benign-355.jpg
# Moved: benign-356.jpg
# Moved: benign-357.jpg
# Moved: benign-358.jpg
# Moved: benign-359.jpg
# Moved: benign-360.jpg
# Moved: benign-361.jpg
# Moved: benign-362.jpg
# Moved: benign-363.jpg
# Moved: benign-364.jpg
# Moved: benign-365.jpg
# Moved: benign-366.jpg
# Moved: benign-367.jpg
# Moved: benign-368.jpg
# Moved: benign-369.jpg
# Moved: benign-370.jpg
# Moved: benign-371.jpg
# Moved: benign-372.jpg
# Moved: benign-373.jpg
# Moved: benign-374.jpg
# Moved: benign-375.jpg
# Moved: benign-376.jpg
# Moved: benign-377.jpg
# Moved: benign-378.jpg
# Moved: benign-379.jpg
# Moved: benign-380.jpg
# Moved: benign-381.jpg
# Moved: benign-382.jpg
# Moved: benign-383.jpg
# Moved: benign-384.jpg
# Moved: benign-385.jpg
# Moved: benign-386.jpg
# Moved: benign-387.jpg
# Moved: benign-388.jpg
# Moved: benign-389.jpg
# Moved: benign-390.jpg
# Moved: benign-391.jpg
# Moved: benign-392.jpg
# Moved: benign-393.jpg
# Moved: benign-394.jpg
# Moved: benign-395.jpg
# Moved: benign-396.jpg
# Moved: benign-397.jpg
# Moved: benign-398.jpg
# Moved: benign-399.jpg
# Moved: benign-400.jpg
# Moved: benign-401.jpg
# Moved: benign-402.jpg
# Moved: benign-403.jpg
# Moved: benign-404.jpg
# Moved: benign-405.jpg
# Moved: benign-406.jpg
# Moved: benign-407.jpg
# Moved: benign-408.jpg
# Moved: benign-409.jpg
# Moved: benign-410.jpg
# Moved: benign-411.jpg
# Moved: benign-412.jpg
# Moved: benign-413.jpg
# Moved: benign-414.jpg
# Moved: benign-415.jpg
# Moved: benign-416.jpg
# Moved: benign-417.jpg
# Moved: benign-418.jpg
# Moved: benign-419.jpg
# Moved: benign-420.jpg
# Moved: benign-421.jpg
# Moved: benign-422.jpg
# Moved: benign-423.jpg
# Moved: benign-424.jpg
# Moved: benign-425.jpg
# Moved: benign-426.jpg
# Moved: benign-427.jpg
# Moved: benign-428.jpg
# Moved: benign-429.jpg
# Moved: benign-430.jpg
# Moved: benign-431.jpg
# Moved: benign-432.jpg
# Moved: benign-433.jpg
# Moved: benign-434.jpg
# Moved: benign-435.jpg
# Moved: benign-436.jpg
# Moved: benign-437.jpg
# Moved: benign-438.jpg
# Moved: benign-439.jpg
# Moved: benign-440.jpg
# Moved: benign-441.jpg
# Moved: benign-442.jpg
# Moved: benign-443.jpg
# Moved: benign-444.jpg
# Moved: benign-445.jpg
# Moved: benign-446.jpg
# Moved: benign-447.jpg
# Moved: benign-448.jpg
# Moved: benign-449.jpg
# Moved: benign-450.jpg
# Moved: benign-451.jpg
# Moved: benign-452.jpg
# Moved: benign-453.jpg
# Moved: benign-454.jpg
# Moved: benign-455.jpg
# Moved: benign-456.jpg
# Moved: benign-457.jpg
# Moved: benign-458.jpg
# Moved: benign-459.jpg
# Moved: benign-460.jpg
# Moved: benign-461.jpg
# Moved: benign-462.jpg
# Moved: benign-463.jpg
# Moved: benign-464.jpg
# Moved: benign-465.jpg
# Moved: benign-466.jpg
# Moved: benign-467.jpg
# Moved: benign-468.jpg
# Moved: benign-469.jpg
# Moved: benign-470.jpg
# Moved: benign-471.jpg
# Moved: benign-472.jpg
# Moved: benign-473.jpg
# Moved: benign-474.jpg
# Moved: benign-475.jpg
# Moved: benign-476.jpg
# Moved: benign-477.jpg
# Moved: benign-478.jpg
# Moved: benign-479.jpg
# Moved: benign-480.jpg
# Moved: benign-481.jpg
# Moved: benign-482.jpg
# Moved: benign-483.jpg
# Moved: benign-484.jpg
# Moved: benign-485.jpg
# Moved: benign-486.jpg
# Moved: benign-487.jpg
# Moved: benign-488.jpg
# Moved: benign-489.jpg
# Moved: benign-490.jpg
# Moved: benign-491.jpg
# Moved: benign-492.jpg
# Moved: benign-493.jpg
# Moved: benign-494.jpg
# Moved: benign-495.jpg
# Moved: benign-496.jpg
# Moved: benign-497.jpg
# Moved: benign-498.jpg
# Moved: benign-499.jpg
# Moved: benign-500.jpg
# Moved: benign-501.jpg
# Moved: benign-502.jpg
# Moved: benign-503.jpg
# Moved: benign-504.jpg
# Moved: benign-505.jpg
# Moved: benign-506.jpg
# Moved: benign-507.jpg
# Moved: benign-508.jpg
# Moved: benign-509.jpg
# Moved: benign-510.jpg
# Moved: benign-511.jpg
# Moved: benign-512.jpg
# Moved: benign-513.jpg
# Moved: benign-514.jpg
# Moved: benign-515.jpg
# Moved: benign-516.jpg
# Moved: benign-517.jpg
# Moved: benign-518.jpg
# Moved: benign-519.jpg
# Moved: benign-520.jpg
# Moved: benign-521.jpg
# Moved: benign-522.jpg
# Moved: benign-523.jpg
# Moved: benign-524.jpg
# Moved: benign-525.jpg
# Moved: benign-526.jpg
# Moved: benign-527.jpg
# Moved: benign-528.jpg
# Moved: benign-529.jpg
# Moved: benign-530.jpg
# Moved: benign-531.jpg
# Moved: benign-532.jpg
# Moved: benign-533.jpg
# Moved: benign-534.jpg
# Moved: benign-535.jpg
# Moved: benign-536.jpg
# Moved: benign-537.jpg
# Moved: benign-538.jpg
# Moved: benign-539.jpg
# Moved: benign-540.jpg
# Moved: benign-541.jpg
# Moved: benign-542.jpg
# Moved: benign-543.jpg
# Moved: benign-544.jpg
# Moved: benign-545.jpg
# Moved: benign-546.jpg
# Moved: benign-547.jpg
# Moved: benign-548.jpg
# Moved: benign-549.jpg
# Moved: benign-550.jpg
# Moved: benign-551.jpg
# Moved: benign-552.jpg
# Moved: benign-553.jpg
# Moved: benign-554.jpg
# Moved: benign-555.jpg
# Moved: benign-556.jpg
# Moved: benign-557.jpg
# Moved: benign-558.jpg
# Moved: benign-559.jpg
# Moved: benign-560.jpg
# Moved: benign-561.jpg
# Moved: benign-562.jpg
# Moved: benign-563.jpg
# Moved: benign-564.jpg
# Moved: benign-565.jpg
# Moved: benign-566.jpg
# Moved: benign-567.jpg
# Moved: benign-568.jpg
# Moved: benign-569.jpg
# Moved: benign-570.jpg
# Moved: benign-571.jpg
# Moved: benign-572.jpg
# Moved: benign-573.jpg
# Moved: benign-574.jpg
# Moved: benign-575.jpg
# Moved: benign-576.jpg
# Moved: benign-577.jpg
# Moved: benign-578.jpg
# Moved: benign-579.jpg
# Moved: benign-580.jpg
# Moved: benign-581.jpg
# Moved: benign-582.jpg
# Moved: benign-583.jpg
# Moved: benign-584.jpg
# Moved: benign-585.jpg
# Moved: benign-586.jpg
# Moved: benign-587.jpg
# Moved: benign-588.jpg
# Moved: benign-589.jpg
# Moved: benign-590.jpg
# Moved: benign-591.jpg
# Moved: benign-592.jpg
# Moved: benign-593.jpg
# Moved: benign-594.jpg
# Moved: benign-595.jpg
# Moved: benign-596.jpg
# Moved: benign-597.jpg
# Moved: benign-598.jpg
# Moved: benign-599.jpg
# Moved: benign-600.jpg
# Moved: benign-601.jpg
# Moved: benign-602.jpg
# Moved: benign-603.jpg
# Moved: benign-604.jpg
# Moved: benign-605.jpg
# Moved: benign-606.jpg
# Moved: benign-607.jpg
# Moved: benign-608.jpg
# Moved: benign-609.jpg
# Moved: benign-610.jpg
# Moved: benign-611.jpg
# Moved: benign-612.jpg
# Moved: benign-613.jpg
# Moved: benign-614.jpg
# Moved: benign-615.jpg
# Moved: benign-616.jpg
# Moved: benign-617.jpg
# Moved: benign-618.jpg
# Moved: benign-619.jpg
# Moved: benign-620.jpg
# Moved: benign-621.jpg
# Moved: benign-622.jpg
# Moved: benign-623.jpg
# Moved: benign-624.jpg
# Moved: benign-625.jpg
# Moved: benign-626.jpg
# Moved: benign-627.jpg
# Moved: benign-628.jpg
# Moved: benign-629.jpg
# Moved: benign-630.jpg
# Moved: benign-631.jpg
# Moved: benign-632.jpg
# Moved: benign-633.jpg
# Moved: benign-634.jpg
# Moved: benign-635.jpg
# Moved: benign-636.jpg
# Moved: benign-637.jpg
# Moved: benign-638.jpg
# Moved: benign-639.jpg
# Moved: benign-640.jpg
# Moved: benign-641.jpg
# Moved: benign-642.jpg
# Moved: benign-643.jpg
# Moved: benign-644.jpg
# Moved: benign-645.jpg
# Moved: benign-646.jpg
# Moved: benign-647.jpg
# Moved: benign-648.jpg
# Moved: benign-649.jpg
# Moved: benign-650.jpg
# Moved: benign-651.jpg
# Moved: benign-652.jpg
# Moved: benign-653.jpg
# Moved: benign-654.jpg
# Moved: benign-655.jpg
# Moved: benign-656.jpg
# Moved: benign-657.jpg
# Moved: benign-658.jpg
# Moved: benign-659.jpg
# Moved: benign-660.jpg
# Moved: benign-661.jpg
# Moved: benign-662.jpg
# Moved: benign-663.jpg
# Moved: benign-664.jpg
# Moved: benign-665.jpg
# Moved: benign-666.jpg
# Moved: benign-667.jpg
# Moved: benign-668.jpg
# Moved: benign-669.jpg
# Moved: benign-670.jpg
# Moved: benign-671.jpg
# Moved: benign-672.jpg
# Moved: benign-673.jpg
# Moved: benign-674.jpg
# Moved: benign-675.jpg
# Moved: benign-676.jpg
# Moved: benign-677.jpg
# Moved: benign-678.jpg
# Moved: benign-679.jpg
# Moved: benign-680.jpg
# Moved: benign-681.jpg
# Moved: benign-682.jpg
# Moved: benign-683.jpg
# Moved: benign-684.jpg
# Moved: benign-685.jpg
# Moved: benign-686.jpg
# Moved: benign-687.jpg
# Moved: benign-688.jpg
# Moved: benign-689.jpg
# Moved: benign-690.jpg
# Moved: benign-691.jpg
# Moved: benign-692.jpg
# Moved: benign-693.jpg
# Moved: benign-694.jpg
# Moved: benign-695.jpg
# Moved: benign-696.jpg
# Moved: benign-697.jpg
# Moved: benign-698.jpg
# Moved: benign-699.jpg
# Moved: benign-700.jpg
# Moved: benign-701.jpg
# Moved: benign-702.jpg
# Moved: benign-703.jpg
# Moved: benign-704.jpg
# Moved: benign-705.jpg
# Moved: benign-706.jpg
# Moved: benign-707.jpg
# Moved: benign-708.jpg
# Moved: benign-709.jpg
# Moved: benign-710.jpg
# Moved: benign-711.jpg
# Moved: benign-712.jpg
# Moved: benign-713.jpg
# Moved: benign-714.jpg
# Moved: benign-715.jpg
# Moved: benign-716.jpg
# Moved: benign-717.jpg
# Moved: benign-718.jpg
# Moved: benign-719.jpg
# Moved: benign-720.jpg
# Moved: benign-721.jpg
# Moved: benign-722.jpg
# Moved: benign-723.jpg
# Moved: benign-724.jpg
# Moved: benign-725.jpg
# Moved: benign-726.jpg
# Moved: benign-727.jpg
# Moved: benign-728.jpg
# Moved: benign-729.jpg
# Moved: benign-730.jpg
# Moved: benign-731.jpg
# Moved: benign-732.jpg
# Moved: benign-733.jpg
# Moved: benign-734.jpg
# Moved: benign-735.jpg
# Moved: benign-736.jpg
# Moved: benign-737.jpg
# Moved: benign-738.jpg
# Moved: benign-739.jpg
# Moved: benign-740.jpg
# Moved: benign-741.jpg
# Moved: benign-742.jpg
# Moved: benign-743.jpg
# Moved: benign-744.jpg
# Moved: benign-745.jpg
# Moved: benign-746.jpg
# Moved: benign-747.jpg
# Moved: benign-748.jpg
# Moved: benign-749.jpg
# Moved: benign-750.jpg
# Moved: benign-751.jpg
# Moved: benign-752.jpg
# Moved: benign-753.jpg
# Moved: benign-754.jpg
# Moved: benign-755.jpg
# Moved: benign-756.jpg
# Moved: benign-757.jpg
# Moved: benign-758.jpg
# Moved: benign-759.jpg
# Moved: benign-760.jpg
# Moved: benign-761.jpg
# Moved: benign-762.jpg
# Moved: benign-763.jpg
# Moved: benign-764.jpg
# Moved: benign-765.jpg
# Moved: benign-766.jpg
# Moved: benign-767.jpg
# Moved: benign-768.jpg
# Moved: benign-769.jpg
# Moved: benign-770.jpg
# Moved: benign-771.jpg
# Moved: benign-772.jpg
# Moved: benign-773.jpg
# Moved: benign-774.jpg
# Moved: benign-775.jpg
# Moved: benign-776.jpg
# Moved: benign-777.jpg
# Moved: benign-778.jpg
# Moved: benign-779.jpg
# Moved: benign-780.jpg
# Moved: benign-781.jpg
# Moved: benign-782.jpg
# Moved: benign-783.jpg
# Moved: benign-784.jpg
# Moved: benign-785.jpg
# Moved: benign-786.jpg
# Moved: benign-787.jpg
# Moved: benign-788.jpg
# Moved: benign-789.jpg
# Moved: benign-790.jpg
# Moved: benign-791.jpg
# Moved: benign-792.jpg
# Moved: benign-793.jpg
# Moved: benign-794.jpg
# Moved: benign-795.jpg
# Moved: benign-796.jpg
# Moved: benign-797.jpg
# Moved: benign-798.jpg
# Moved: benign-799.jpg
# Moved: benign-800.jpg
# Moved: benign-801.jpg
# Moved: benign-802.jpg
# Moved: benign-803.jpg
# Moved: benign-804.jpg
# Moved: benign-805.jpg
# Moved: benign-806.jpg
# Moved: benign-807.jpg
# Moved: benign-808.jpg
# Moved: benign-809.jpg
# Moved: benign-810.jpg
# Moved: benign-811.jpg
# Moved: benign-812.jpg
# Moved: benign-813.jpg
# Moved: benign-814.jpg
# Moved: benign-815.jpg
# Moved: benign-816.jpg
# Moved: benign-817.jpg
# Moved: benign-818.jpg
# Moved: benign-819.jpg
# Moved: benign-820.jpg
# Moved: benign-821.jpg
# Moved: benign-822.jpg
# Moved: benign-823.jpg
# Moved: benign-824.jpg
# Moved: benign-825.jpg
# Moved: benign-826.jpg
# Moved: benign-827.jpg
# Moved: benign-828.jpg
# Moved: benign-829.jpg
# Moved: benign-830.jpg
# Moved: benign-831.jpg
# Moved: benign-832.jpg
# Moved: benign-833.jpg
# Moved: benign-834.jpg
# Moved: benign-835.jpg
# Moved: benign-836.jpg
# Moved: benign-837.jpg
# Moved: benign-838.jpg
# Moved: benign-839.jpg
# Moved: benign-840.jpg
# Moved: benign-841.jpg
# Moved: benign-842.jpg
# Moved: benign-843.jpg
# Moved: benign-844.jpg
# Moved: benign-845.jpg
# Moved: benign-846.jpg
# Moved: benign-847.jpg
# Moved: benign-848.jpg
# Moved: benign-849.jpg
# Moved: benign-850.jpg
# Moved: benign-851.jpg
# Moved: benign-852.jpg
# Moved: benign-853.jpg
# Moved: benign-854.jpg
# Moved: benign-855.jpg
# Moved: benign-856.jpg
# Moved: benign-857.jpg
# Moved: benign-858.jpg
# Moved: benign-859.jpg
# Moved: benign-860.jpg
# Moved: benign-861.jpg
# Moved: benign-862.jpg
# Moved: benign-863.jpg
# Moved: benign-864.jpg
# Moved: benign-865.jpg
# Moved: benign-866.jpg
# Moved: benign-867.jpg
# Moved: benign-868.jpg
# Moved: benign-869.jpg
# Moved: benign-870.jpg
# Moved: benign-871.jpg
# Moved: benign-872.jpg
# Moved: benign-873.jpg
# Moved: benign-874.jpg
# Moved: benign-875.jpg
# Moved: benign-876.jpg
# Moved: benign-877.jpg
# Moved: benign-878.jpg
# Moved: benign-879.jpg
# Moved: benign-880.jpg
# Moved: benign-881.jpg
# Moved: benign-882.jpg
# Moved: benign-883.jpg
# Moved: benign-884.jpg
# Moved: benign-885.jpg
# Moved: benign-886.jpg
# Moved: benign-887.jpg
# Moved: benign-888.jpg
# Moved: benign-889.jpg
# Moved: benign-890.jpg
# Moved: benign-891.jpg
# Moved: benign-892.jpg
# Moved: benign-893.jpg
# Moved: benign-894.jpg
# Moved: benign-895.jpg
# Moved: benign-896.jpg
# Moved: benign-897.jpg
# Moved: benign-898.jpg
# Moved: benign-899.jpg
# Moved: benign-900.jpg
# Moved: benign-901.jpg
# Moved: benign-902.jpg
# Moved: benign-903.jpg
# Moved: benign-904.jpg
# Moved: benign-905.jpg
# Moved: benign-906.jpg
# Moved: benign-907.jpg
# Moved: benign-908.jpg
# Moved: benign-909.jpg
# Moved: benign-910.jpg
# Moved: benign-911.jpg
# Moved: benign-912.jpg
# Moved: benign-913.jpg
# Moved: benign-914.jpg
# Moved: benign-915.jpg
# Moved: benign-916.jpg
# Moved: benign-917.jpg
# Moved: benign-918.jpg
# Moved: benign-919.jpg
# Moved: benign-920.jpg
# Moved: benign-921.jpg
# Moved: benign-922.jpg
# Moved: benign-923.jpg
# Moved: benign-924.jpg
# Moved: benign-925.jpg
# Moved: benign-926.jpg
# Moved: benign-927.jpg
# Moved: benign-928.jpg
# Moved: benign-929.jpg
# Moved: benign-930.jpg
# Moved: benign-931.jpg
# Moved: benign-932.jpg
# Moved: benign-933.jpg
# Moved: benign-934.jpg
# Moved: benign-935.jpg
# Moved: benign-936.jpg
# Moved: benign-937.jpg
# Moved: benign-938.jpg
# Moved: benign-939.jpg
# Moved: benign-940.jpg
# Moved: benign-941.jpg
# Moved: benign-942.jpg
# Moved: benign-943.jpg
# Moved: benign-944.jpg
# Moved: benign-945.jpg
# Moved: benign-946.jpg
# Moved: benign-947.jpg
# Moved: benign-948.jpg
# Moved: benign-949.jpg
# Moved: benign-950.jpg
# Moved: benign-951.jpg
# Moved: benign-952.jpg
# Moved: benign-953.jpg
# Moved: benign-954.jpg
# Moved: benign-955.jpg
# Moved: benign-956.jpg
# Moved: benign-957.jpg
# Moved: benign-958.jpg
# Moved: benign-959.jpg
# Moved: benign-960.jpg
# Moved: benign-961.jpg
# Moved: benign-962.jpg
# Moved: benign-963.jpg
# Moved: benign-964.jpg
# Moved: benign-965.jpg
# Moved: benign-966.jpg
# Moved: benign-967.jpg
# Moved: benign-968.jpg
# Moved: benign-969.jpg
# Moved: benign-970.jpg
# Moved: benign-971.jpg
# Moved: benign-972.jpg
# Moved: benign-973.jpg
# Moved: benign-974.jpg
# Moved: benign-975.jpg
# Moved: benign-976.jpg
# Moved: benign-977.jpg
# Moved: benign-978.jpg
# Moved: benign-979.jpg
# Moved: benign-980.jpg
# Moved: benign-981.jpg
# Moved: benign-982.jpg
# Moved: benign-983.jpg
# Moved: benign-984.jpg
# Moved: benign-985.jpg
# Moved: benign-986.jpg
# Moved: benign-987.jpg
# Moved: benign-988.jpg
# Moved: benign-989.jpg
# Moved: benign-990.jpg
# Moved: benign-991.jpg
# Moved: benign-992.jpg
# Moved: benign-993.jpg
# Moved: benign-994.jpg
# Moved: benign-995.jpg
# Moved: benign-996.jpg
# Moved: benign-997.jpg
# Moved: benign-998.jpg
# Moved: benign-999.jpg
# Moved: benign-1000.jpg
# Moved: benign-1001.jpg
# Moved: benign-1002.jpg
# Moved: benign-1003.jpg
# Moved: benign-1004.jpg
# Moved: benign-1005.jpg
# Moved: benign-1006.jpg
# Moved: benign-1007.jpg
# Moved: benign-1008.jpg
# Moved: benign-1009.jpg
# Moved: benign-1010.jpg
# Moved: benign-1011.jpg
# Moved: benign-1012.jpg
# Moved: benign-1013.jpg
# Moved: benign-1014.jpg
# Moved: benign-1015.jpg
# Moved: benign-1016.jpg
# Moved: benign-1017.jpg
# Moved: benign-1018.jpg
# Moved: benign-1019.jpg
# Moved: benign-1020.jpg
# Moved: benign-1021.jpg
# Moved: benign-1022.jpg
# Moved: benign-1023.jpg
# Moved: benign-1024.jpg
# Moved: benign-1025.jpg
# Moved: benign-1026.jpg
# Moved: benign-1027.jpg
# Moved: benign-1028.jpg
# Moved: benign-1029.jpg
# Moved: benign-1030.jpg
# Moved: benign-1031.jpg
# Moved: benign-1032.jpg
# Moved: benign-1033.jpg
# Moved: benign-1034.jpg
# Moved: benign-1035.jpg
# Moved: benign-1036.jpg
# Moved: benign-1037.jpg
# Moved: benign-1038.jpg
# Moved: benign-1039.jpg
# Moved: benign-1040.jpg
# Moved: benign-1041.jpg
# Moved: benign-1042.jpg
# Moved: benign-1043.jpg
# Moved: benign-1044.jpg
# Moved: benign-1045.jpg
# Moved: benign-1046.jpg
# Moved: benign-1047.jpg
# Moved: benign-1048.jpg
# Moved: benign-1049.jpg
# Moved: benign-1050.jpg
# Moved: benign-1051.jpg
# Moved: benign-1052.jpg
# Moved: benign-1053.jpg
# Moved: benign-1054.jpg
# Moved: benign-1055.jpg
# Moved: benign-1056.jpg
# Moved: benign-1057.jpg
# Moved: benign-1058.jpg
# Moved: benign-1059.jpg
# Moved: benign-1060.jpg
# Moved: benign-1061.jpg
# Moved: benign-1062.jpg
# Moved: benign-1063.jpg
# Moved: benign-1064.jpg
# Moved: benign-1065.jpg
# Moved: benign-1066.jpg
# Moved: benign-1067.jpg
# Moved: benign-1068.jpg
# Moved: benign-1069.jpg
# Moved: benign-1070.jpg
# Moved: benign-1071.jpg
# Moved: benign-1072.jpg
# Moved: benign-1073.jpg
# Moved: benign-1074.jpg
# Moved: benign-1075.jpg
# Moved: benign-1076.jpg
# Moved: benign-1077.jpg
# Moved: benign-1078.jpg
# Moved: benign-1079.jpg
# Moved: benign-1080.jpg
# Moved: benign-1081.jpg
# Moved: benign-1082.jpg
# Moved: benign-1083.jpg
# Moved: benign-1084.jpg
# Moved: benign-1085.jpg
# Moved: benign-1086.jpg
# Moved: benign-1087.jpg
# Moved: benign-1088.jpg
# Moved: benign-1089.jpg
# Moved: benign-1090.jpg
# Moved: benign-1091.jpg
# Moved: benign-1092.jpg
# Moved: benign-1093.jpg
# Moved: benign-1094.jpg
# Moved: benign-1095.jpg
# Moved: benign-1096.jpg
# Moved: benign-1097.jpg
# Moved: benign-1098.jpg
# Moved: benign-1099.jpg
# Moved: benign-1100.jpg
# Moved: benign-1101.jpg
# Moved: benign-1102.jpg
# Moved: benign-1103.jpg
# Moved: benign-1104.jpg
# Moved: benign-1105.jpg
# Moved: benign-1106.jpg
# Moved: benign-1107.jpg
# Moved: benign-1108.jpg
# Moved: benign-1109.jpg
# Moved: benign-1110.jpg
# Moved: benign-1111.jpg
# Moved: benign-1112.jpg
# Moved: benign-1113.jpg
# Moved: benign-1114.jpg
# Moved: benign-1115.jpg
# Moved: benign-1116.jpg
# Moved: benign-1117.jpg
# Moved: benign-1118.jpg
# Moved: benign-1119.jpg
# Moved: benign-1120.jpg
# Moved: benign-1121.jpg
# Moved: benign-1122.jpg
# Moved: benign-1123.jpg
# Moved: benign-1124.jpg
# Moved: benign-1125.jpg
# Moved: benign-1126.jpg
# Moved: benign-1127.jpg
# Moved: benign-1128.jpg
# Moved: benign-1129.jpg
# Moved: benign-1130.jpg
# Moved: benign-1131.jpg
# Moved: benign-1132.jpg
# Moved: benign-1133.jpg
# Moved: benign-1134.jpg
# Moved: benign-1135.jpg
# Moved: benign-1136.jpg
# Moved: benign-1137.jpg
# Moved: benign-1138.jpg
# Moved: benign-1139.jpg
# Moved: benign-1140.jpg
# Moved: benign-1141.jpg
# Moved: benign-1142.jpg
# Moved: benign-1143.jpg
# Moved: benign-1144.jpg
# Moved: benign-1145.jpg
# Moved: benign-1146.jpg
# Moved: benign-1147.jpg
# Moved: benign-1148.jpg
# Moved: benign-1149.jpg
# Moved: benign-1150.jpg
# Moved: benign-1151.jpg
# Moved: benign-1152.jpg
# Moved: benign-1153.jpg
# Moved: benign-1154.jpg
# Moved: benign-1155.jpg
# Moved: benign-1156.jpg
# Moved: benign-1157.jpg
# Moved: benign-1158.jpg
# Moved: benign-1159.jpg
# Moved: benign-1160.jpg
# Moved: benign-1161.jpg
# Moved: benign-1162.jpg
# Moved: benign-1163.jpg
# Moved: benign-1164.jpg
# Moved: benign-1165.jpg
# Moved: benign-1166.jpg
# Moved: benign-1167.jpg
# Moved: benign-1168.jpg
# Moved: benign-1169.jpg
# Moved: benign-1170.jpg
# Moved: benign-1171.jpg
# Moved: benign-1172.jpg
# Moved: benign-1173.jpg
# Moved: benign-1174.jpg
# Moved: benign-1175.jpg
# Moved: benign-1176.jpg
# Moved: benign-1177.jpg
# Moved: benign-1178.jpg
# Moved: benign-1179.jpg
# Moved: benign-1180.jpg
# Moved: benign-1181.jpg
# Moved: benign-1182.jpg
# Moved: benign-1183.jpg
# Moved: benign-1184.jpg
# Moved: benign-1185.jpg
# Moved: benign-1186.jpg
# Moved: benign-1187.jpg
# Moved: benign-1188.jpg
# Moved: benign-1189.jpg
# Moved: benign-1190.jpg
# Moved: benign-1191.jpg
# Moved: benign-1192.jpg
# Moved: benign-1193.jpg
# Moved: benign-1194.jpg
# Moved: benign-1195.jpg
# Moved: benign-1196.jpg
# Moved: benign-1197.jpg
# Moved: benign-1198.jpg
# Moved: benign-1199.jpg
# Moved: benign-1200.jpg
# Moved: benign-1201.jpg
# Moved: benign-1202.jpg
# Moved: benign-1203.jpg
# Moved: benign-1204.jpg
# Moved: benign-1205.jpg
# Moved: benign-1206.jpg
# Moved: benign-1207.jpg
# Moved: benign-1208.jpg
# Moved: benign-1209.jpg
# Moved: benign-1210.jpg
# Moved: benign-1211.jpg
# Moved: benign-1212.jpg
# Moved: benign-1213.jpg
# Moved: benign-1214.jpg
# Moved: benign-1215.jpg
# Moved: benign-1216.jpg
# Moved: benign-1217.jpg
# Moved: benign-1218.jpg
# Moved: benign-1219.jpg
# Moved: benign-1220.jpg
# Moved: benign-1221.jpg
# Moved: benign-1222.jpg
# Moved: benign-1223.jpg
# Moved: benign-1224.jpg
# Moved: benign-1225.jpg
# Moved: benign-1226.jpg
# Moved: benign-1227.jpg
# Moved: benign-1228.jpg
# Moved: benign-1229.jpg
# Moved: benign-1230.jpg
# Moved: benign-1231.jpg
# Moved: benign-1232.jpg
# Moved: benign-1233.jpg
# Moved: benign-1234.jpg
# Moved: benign-1235.jpg
# Moved: benign-1236.jpg
# Moved: benign-1237.jpg
# Moved: benign-1238.jpg
# Moved: benign-1239.jpg
# Moved: benign-1240.jpg
# Moved: benign-1241.jpg
# Moved: benign-1242.jpg
# Moved: benign-1243.jpg
# Moved: benign-1244.jpg
# Moved: benign-1245.jpg
# Moved: benign-1246.jpg
# Moved: benign-1247.jpg
# Moved: benign-1248.jpg
# Moved: benign-1249.jpg
# Moved: benign-1250.jpg
# Moved: benign-1251.jpg
# Moved: benign-1252.jpg
# Moved: benign-1253.jpg
# Moved: benign-1254.jpg
# Moved: benign-1255.jpg
# Moved: benign-1256.jpg
# Moved: benign-1257.jpg
# Moved: benign-1258.jpg
# Moved: benign-1259.jpg
# Moved: benign-1260.jpg
# Moved: benign-1261.jpg
# Moved: benign-1262.jpg
# Moved: benign-1263.jpg
# Moved: benign-1264.jpg
# Moved: benign-1265.jpg
# Moved: benign-1266.jpg
# Moved: benign-1267.jpg
# Moved: benign-1268.jpg
# Moved: benign-1269.jpg
# Moved: benign-1270.jpg
# Moved: benign-1271.jpg
# Moved: benign-1272.jpg
# Moved: benign-1273.jpg
# Moved: benign-1274.jpg
# Moved: benign-1275.jpg
# Moved: benign-1276.jpg
# Moved: benign-1277.jpg
# Moved: benign-1278.jpg
# Moved: benign-1279.jpg
# Moved: benign-1280.jpg
# Moved: benign-1281.jpg
# Moved: benign-1282.jpg
# Moved: benign-1283.jpg
# Moved: benign-1284.jpg
# Moved: benign-1285.jpg
# Moved: benign-1286.jpg
# Moved: benign-1287.jpg
# Moved: benign-1288.jpg
# Moved: benign-1289.jpg
# Moved: benign-1290.jpg
# Moved: benign-1291.jpg
# Moved: benign-1292.jpg
# Moved: benign-1293.jpg
# Moved: benign-1294.jpg
# Moved: benign-1295.jpg
# Moved: benign-1296.jpg
# Moved: benign-1297.jpg
# Moved: benign-1298.jpg
# Moved: benign-1299.jpg
# Moved: benign-1300.jpg
# Moved: benign-1301.jpg
# Moved: benign-1302.jpg
# Moved: benign-1303.jpg
# Moved: benign-1304.jpg
# Moved: benign-1305.jpg
# Moved: benign-1306.jpg
# Moved: benign-1307.jpg
# Moved: benign-1308.jpg
# Moved: benign-1309.jpg
# Moved: benign-1310.jpg
# Moved: benign-1311.jpg
# Moved: benign-1312.jpg
# Moved: benign-1313.jpg
# Moved: benign-1314.jpg
# Moved: benign-1315.jpg
# Moved: benign-1316.jpg
# Moved: benign-1317.jpg
# Moved: benign-1318.jpg
# Moved: benign-1319.jpg
# Moved: benign-1320.jpg
# Moved: malignant-1112.jpg
# Moved: malignant-1113.jpg
# Moved: malignant-1114.jpg
# Moved: malignant-1115.jpg
# Moved: malignant-1116.jpg
# Moved: malignant-1117.jpg
# Moved: malignant-1118.jpg
# Moved: malignant-1119.jpg
# Moved: malignant-1120.jpg
# Moved: malignant-1121.jpg
# Moved: malignant-1122.jpg
# Moved: malignant-1123.jpg
# Moved: malignant-1124.jpg
# Moved: malignant-1125.jpg
# Moved: malignant-1126.jpg
# Moved: malignant-1127.jpg
# Moved: malignant-1128.jpg
# Moved: malignant-1129.jpg
# Moved: malignant-1130.jpg
# Moved: malignant-1131.jpg
# Moved: malignant-1132.jpg
# Moved: malignant-1133.jpg
# Moved: malignant-1134.jpg
# Moved: malignant-1135.jpg
# Moved: malignant-1136.jpg
# Moved: malignant-1137.jpg
# Moved: malignant-1138.jpg
# Moved: malignant-1139.jpg
# Moved: malignant-1140.jpg
# Moved: malignant-1141.jpg
# Moved: malignant-1142.jpg
# Moved: malignant-1143.jpg
# Moved: malignant-1144.jpg
# Moved: malignant-1145.jpg
# Moved: malignant-1146.jpg
# Moved: malignant-1147.jpg
# Moved: malignant-1148.jpg
# Moved: malignant-1149.jpg
# Moved: malignant-1150.jpg
# Moved: malignant-1151.jpg
# Moved: malignant-1152.jpg
# Moved: malignant-1153.jpg
# Moved: malignant-1154.jpg
# Moved: malignant-1155.jpg
# Moved: malignant-1156.jpg
# Moved: malignant-1157.jpg
# Moved: malignant-1158.jpg
# Moved: malignant-1159.jpg
# Moved: malignant-1160.jpg
# Moved: malignant-1161.jpg
# Moved: malignant-1162.jpg
# Moved: malignant-1163.jpg
# Moved: malignant-1164.jpg
# Moved: malignant-1165.jpg
# Moved: malignant-1166.jpg
# Moved: malignant-1167.jpg
# Moved: malignant-1168.jpg
# Moved: malignant-1169.jpg
# Moved: malignant-1170.jpg
# Moved: malignant-1171.jpg
# Moved: malignant-1172.jpg
# Moved: malignant-1173.jpg
# Moved: malignant-1174.jpg
# Moved: malignant-1175.jpg
# Moved: malignant-1176.jpg
# Moved: malignant-1177.jpg
# Moved: malignant-1178.jpg
# Moved: malignant-1179.jpg
# Moved: malignant-1180.jpg
# Moved: malignant-1181.jpg
# Moved: malignant-1182.jpg
# Moved: malignant-1183.jpg
# Moved: malignant-1184.jpg
# Moved: malignant-1185.jpg
# Moved: malignant-1186.jpg
# Moved: malignant-1187.jpg
# Moved: malignant-1188.jpg
# Moved: malignant-1189.jpg
# Moved: malignant-1190.jpg
# Moved: malignant-1191.jpg
# Moved: malignant-1192.jpg
# Moved: malignant-1193.jpg
# Moved: malignant-1194.jpg
# Moved: malignant-1195.jpg
# Moved: malignant-1196.jpg
# Moved: malignant-1197.jpg
# Moved: labels.json

# %%
import os
import shutil

# Moving being and malignant testing images into one file for ease of access

source_folder = r"/content/drive/MyDrive/kaggle/data/test/benign/"
destination_folder = r"/content/drive/MyDrive/kaggle/c_data_test/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # move only files
    if os.path.isfile(source):
        shutil.move(source, destination)
        print('Moved:', file_name)

source_folder = r"/content/drive/MyDrive/kaggle/data/test/malignant/"
destination_folder = r"/content/drive/MyDrive/kaggle/c_data_test/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # move only files
    if os.path.isfile(source):
        shutil.move(source, destination)
        print('Moved:', file_name)
# Out:
# Moved: benign-1.jpg
# Moved: benign-2.jpg
# Moved: benign-3.jpg
# Moved: benign-4.jpg
# Moved: benign-5.jpg
# Moved: benign-6.jpg
# Moved: benign-7.jpg
# Moved: benign-8.jpg
# Moved: benign-9.jpg
# Moved: benign-10.jpg
# Moved: benign-11.jpg
# Moved: benign-12.jpg
# Moved: benign-13.jpg
# Moved: benign-14.jpg
# Moved: benign-15.jpg
# Moved: benign-16.jpg
# Moved: benign-17.jpg
# Moved: benign-18.jpg
# Moved: benign-19.jpg
# Moved: benign-20.jpg
# Moved: benign-21.jpg
# Moved: benign-22.jpg
# Moved: benign-23.jpg
# Moved: benign-24.jpg
# Moved: benign-25.jpg
# Moved: benign-26.jpg
# Moved: benign-27.jpg
# Moved: benign-28.jpg
# Moved: benign-29.jpg
# Moved: benign-30.jpg
# Moved: benign-31.jpg
# Moved: benign-32.jpg
# Moved: benign-33.jpg
# Moved: benign-34.jpg
# Moved: benign-35.jpg
# Moved: benign-36.jpg
# Moved: benign-37.jpg
# Moved: benign-38.jpg
# Moved: benign-39.jpg
# Moved: benign-40.jpg
# Moved: benign-41.jpg
# Moved: benign-42.jpg
# Moved: benign-43.jpg
# Moved: benign-44.jpg
# Moved: benign-45.jpg
# Moved: benign-46.jpg
# Moved: benign-47.jpg
# Moved: benign-48.jpg
# Moved: benign-49.jpg
# Moved: benign-50.jpg
# Moved: benign-51.jpg
# Moved: benign-52.jpg
# Moved: benign-53.jpg
# Moved: benign-54.jpg
# Moved: benign-55.jpg
# Moved: benign-56.jpg
# Moved: benign-57.jpg
# Moved: benign-58.jpg
# Moved: benign-59.jpg
# Moved: benign-60.jpg
# Moved: benign-61.jpg
# Moved: benign-62.jpg
# Moved: benign-63.jpg
# Moved: benign-64.jpg
# Moved: benign-65.jpg
# Moved: benign-66.jpg
# Moved: benign-67.jpg
# Moved: benign-68.jpg
# Moved: benign-69.jpg
# Moved: benign-70.jpg
# Moved: benign-71.jpg
# Moved: benign-72.jpg
# Moved: benign-73.jpg
# Moved: benign-74.jpg
# Moved: benign-75.jpg
# Moved: benign-76.jpg
# Moved: benign-77.jpg
# Moved: benign-78.jpg
# Moved: benign-79.jpg
# Moved: benign-80.jpg
# Moved: benign-81.jpg
# Moved: benign-82.jpg
# Moved: benign-83.jpg
# Moved: benign-84.jpg
# Moved: benign-85.jpg
# Moved: benign-86.jpg
# Moved: benign-87.jpg
# Moved: benign-88.jpg
# Moved: benign-89.jpg
# Moved: benign-90.jpg
# Moved: benign-91.jpg
# Moved: benign-92.jpg
# Moved: benign-93.jpg
# Moved: benign-94.jpg
# Moved: benign-95.jpg
# Moved: benign-96.jpg
# Moved: benign-97.jpg
# Moved: benign-98.jpg
# Moved: benign-99.jpg
# Moved: benign-100.jpg
# Moved: benign-101.jpg
# Moved: benign-102.jpg
# Moved: benign-103.jpg
# Moved: benign-104.jpg
# Moved: benign-105.jpg
# Moved: benign-106.jpg
# Moved: benign-107.jpg
# Moved: benign-108.jpg
# Moved: benign-109.jpg
# Moved: benign-110.jpg
# Moved: benign-111.jpg
# Moved: benign-112.jpg
# Moved: benign-113.jpg
# Moved: benign-114.jpg
# Moved: benign-115.jpg
# Moved: benign-116.jpg
# Moved: benign-117.jpg
# Moved: benign-118.jpg
# Moved: benign-119.jpg
# Moved: benign-120.jpg
# Moved: benign-121.jpg
# Moved: benign-122.jpg
# Moved: benign-123.jpg
# Moved: benign-124.jpg
# Moved: benign-125.jpg
# Moved: benign-126.jpg
# Moved: benign-127.jpg
# Moved: benign-128.jpg
# Moved: benign-129.jpg
# Moved: benign-130.jpg
# Moved: benign-131.jpg
# Moved: benign-132.jpg
# Moved: benign-133.jpg
# Moved: benign-134.jpg
# Moved: benign-135.jpg
# Moved: benign-136.jpg
# Moved: benign-137.jpg
# Moved: benign-138.jpg
# Moved: benign-139.jpg
# Moved: benign-140.jpg
# Moved: benign-141.jpg
# Moved: benign-142.jpg
# Moved: benign-143.jpg
# Moved: benign-144.jpg
# Moved: benign-145.jpg
# Moved: benign-146.jpg
# Moved: benign-147.jpg
# Moved: benign-148.jpg
# Moved: benign-149.jpg
# Moved: benign-150.jpg
# Moved: benign-151.jpg
# Moved: benign-152.jpg
# Moved: benign-153.jpg
# Moved: benign-154.jpg
# Moved: benign-155.jpg
# Moved: benign-156.jpg
# Moved: benign-157.jpg
# Moved: benign-158.jpg
# Moved: benign-159.jpg
# Moved: benign-160.jpg
# Moved: benign-161.jpg
# Moved: benign-162.jpg
# Moved: benign-163.jpg
# Moved: benign-164.jpg
# Moved: benign-165.jpg
# Moved: benign-166.jpg
# Moved: benign-167.jpg
# Moved: benign-168.jpg
# Moved: benign-169.jpg
# Moved: benign-170.jpg
# Moved: benign-171.jpg
# Moved: benign-172.jpg
# Moved: benign-173.jpg
# Moved: benign-174.jpg
# Moved: benign-175.jpg
# Moved: benign-176.jpg
# Moved: benign-177.jpg
# Moved: benign-178.jpg
# Moved: benign-179.jpg
# Moved: benign-180.jpg
# Moved: benign-181.jpg
# Moved: benign-182.jpg
# Moved: benign-183.jpg
# Moved: benign-184.jpg
# Moved: benign-185.jpg
# Moved: benign-186.jpg
# Moved: benign-187.jpg
# Moved: benign-188.jpg
# Moved: benign-189.jpg
# Moved: benign-190.jpg
# Moved: benign-191.jpg
# Moved: benign-192.jpg
# Moved: benign-193.jpg
# Moved: benign-194.jpg
# Moved: benign-195.jpg
# Moved: benign-196.jpg
# Moved: benign-197.jpg
# Moved: benign-198.jpg
# Moved: benign-199.jpg
# Moved: benign-200.jpg
# Moved: benign-201.jpg
# Moved: benign-202.jpg
# Moved: benign-203.jpg
# Moved: benign-204.jpg
# Moved: benign-205.jpg
# Moved: benign-206.jpg
# Moved: benign-207.jpg
# Moved: benign-208.jpg
# Moved: benign-209.jpg
# Moved: benign-210.jpg
# Moved: benign-211.jpg
# Moved: benign-212.jpg
# Moved: benign-213.jpg
# Moved: benign-214.jpg
# Moved: benign-215.jpg
# Moved: benign-216.jpg
# Moved: benign-217.jpg
# Moved: benign-218.jpg
# Moved: benign-219.jpg
# Moved: benign-220.jpg
# Moved: benign-221.jpg
# Moved: benign-222.jpg
# Moved: benign-223.jpg
# Moved: benign-224.jpg
# Moved: benign-225.jpg
# Moved: benign-226.jpg
# Moved: benign-227.jpg
# Moved: benign-228.jpg
# Moved: benign-229.jpg
# Moved: benign-230.jpg
# Moved: benign-231.jpg
# Moved: benign-232.jpg
# Moved: benign-233.jpg
# Moved: benign-234.jpg
# Moved: benign-235.jpg
# Moved: benign-236.jpg
# Moved: benign-237.jpg
# Moved: benign-238.jpg
# Moved: benign-239.jpg
# Moved: benign-240.jpg
# Moved: benign-241.jpg
# Moved: benign-242.jpg
# Moved: benign-243.jpg
# Moved: benign-244.jpg
# Moved: benign-245.jpg
# Moved: benign-246.jpg
# Moved: benign-247.jpg
# Moved: benign-248.jpg
# Moved: benign-249.jpg
# Moved: benign-250.jpg
# Moved: benign-251.jpg
# Moved: benign-252.jpg
# Moved: benign-253.jpg
# Moved: benign-254.jpg
# Moved: benign-255.jpg
# Moved: benign-256.jpg
# Moved: benign-257.jpg
# Moved: benign-258.jpg
# Moved: benign-259.jpg
# Moved: benign-260.jpg
# Moved: benign-261.jpg
# Moved: benign-262.jpg
# Moved: benign-263.jpg
# Moved: benign-264.jpg
# Moved: benign-265.jpg
# Moved: benign-266.jpg
# Moved: benign-267.jpg
# Moved: benign-268.jpg
# Moved: benign-269.jpg
# Moved: benign-270.jpg
# Moved: benign-271.jpg
# Moved: benign-272.jpg
# Moved: benign-273.jpg
# Moved: benign-274.jpg
# Moved: benign-275.jpg
# Moved: benign-276.jpg
# Moved: benign-277.jpg
# Moved: benign-278.jpg
# Moved: benign-279.jpg
# Moved: benign-280.jpg
# Moved: benign-281.jpg
# Moved: benign-282.jpg
# Moved: benign-283.jpg
# Moved: benign-284.jpg
# Moved: benign-285.jpg
# Moved: benign-286.jpg
# Moved: benign-287.jpg
# Moved: benign-288.jpg
# Moved: benign-289.jpg
# Moved: benign-290.jpg
# Moved: benign-291.jpg
# Moved: benign-292.jpg
# Moved: benign-293.jpg
# Moved: benign-294.jpg
# Moved: benign-295.jpg
# Moved: benign-296.jpg
# Moved: benign-297.jpg
# Moved: benign-298.jpg
# Moved: benign-299.jpg
# Moved: benign-300.jpg
# Moved: benign-301.jpg
# Moved: benign-302.jpg
# Moved: benign-303.jpg
# Moved: benign-304.jpg
# Moved: benign-305.jpg
# Moved: benign-306.jpg
# Moved: benign-307.jpg
# Moved: benign-308.jpg
# Moved: benign-309.jpg
# Moved: benign-310.jpg
# Moved: benign-311.jpg
# Moved: benign-312.jpg
# Moved: benign-313.jpg
# Moved: benign-314.jpg
# Moved: benign-315.jpg
# Moved: benign-316.jpg
# Moved: benign-317.jpg
# Moved: benign-318.jpg
# Moved: benign-319.jpg
# Moved: benign-320.jpg
# Moved: benign-321.jpg
# Moved: benign-322.jpg
# Moved: benign-323.jpg
# Moved: benign-324.jpg
# Moved: benign-325.jpg
# Moved: benign-326.jpg
# Moved: benign-327.jpg
# Moved: benign-328.jpg
# Moved: benign-329.jpg
# Moved: benign-330.jpg
# Moved: benign-331.jpg
# Moved: benign-332.jpg
# Moved: benign-333.jpg
# Moved: benign-334.jpg
# Moved: benign-335.jpg
# Moved: benign-336.jpg
# Moved: benign-337.jpg
# Moved: benign-338.jpg
# Moved: benign-339.jpg
# Moved: benign-340.jpg
# Moved: benign-341.jpg
# Moved: benign-342.jpg
# Moved: benign-343.jpg
# Moved: benign-344.jpg
# Moved: benign-345.jpg
# Moved: benign-346.jpg
# Moved: benign-347.jpg
# Moved: benign-348.jpg
# Moved: benign-349.jpg
# Moved: benign-350.jpg
# Moved: benign-351.jpg
# Moved: benign-352.jpg
# Moved: benign-353.jpg
# Moved: benign-354.jpg
# Moved: benign-355.jpg
# Moved: benign-356.jpg
# Moved: benign-357.jpg
# Moved: benign-358.jpg
# Moved: benign-359.jpg
# Moved: benign-360.jpg
# Moved: malignant-1.jpg
# Moved: malignant-2.jpg
# Moved: malignant-3.jpg
# Moved: malignant-4.jpg
# Moved: malignant-5.jpg
# Moved: malignant-6.jpg
# Moved: malignant-7.jpg
# Moved: malignant-8.jpg
# Moved: malignant-9.jpg
# Moved: malignant-10.jpg
# Moved: malignant-11.jpg
# Moved: malignant-12.jpg
# Moved: malignant-13.jpg
# Moved: malignant-14.jpg
# Moved: malignant-15.jpg
# Moved: malignant-16.jpg
# Moved: malignant-17.jpg
# Moved: malignant-18.jpg
# Moved: malignant-19.jpg
# Moved: malignant-20.jpg
# Moved: malignant-21.jpg
# Moved: malignant-22.jpg
# Moved: malignant-23.jpg
# Moved: malignant-24.jpg
# Moved: malignant-25.jpg
# Moved: malignant-26.jpg
# Moved: malignant-27.jpg
# Moved: malignant-28.jpg
# Moved: malignant-29.jpg
# Moved: malignant-30.jpg
# Moved: malignant-31.jpg
# Moved: malignant-32.jpg
# Moved: malignant-33.jpg
# Moved: malignant-34.jpg
# Moved: malignant-35.jpg
# Moved: malignant-36.jpg
# Moved: malignant-37.jpg
# Moved: malignant-38.jpg
# Moved: malignant-39.jpg
# Moved: malignant-40.jpg
# Moved: malignant-41.jpg
# Moved: malignant-42.jpg
# Moved: malignant-43.jpg
# Moved: malignant-44.jpg
# Moved: malignant-45.jpg
# Moved: malignant-46.jpg
# Moved: malignant-47.jpg
# Moved: malignant-48.jpg
# Moved: malignant-49.jpg
# Moved: malignant-50.jpg
# Moved: malignant-51.jpg
# Moved: malignant-52.jpg
# Moved: malignant-53.jpg
# Moved: malignant-54.jpg
# Moved: malignant-55.jpg
# Moved: malignant-56.jpg
# Moved: malignant-57.jpg
# Moved: malignant-58.jpg
# Moved: malignant-59.jpg
# Moved: malignant-60.jpg
# Moved: malignant-61.jpg
# Moved: malignant-62.jpg
# Moved: malignant-269.jpg
# Moved: malignant-270.jpg
# Moved: malignant-271.jpg
# Moved: malignant-272.jpg
# Moved: malignant-273.jpg
# Moved: malignant-274.jpg
# Moved: malignant-275.jpg
# Moved: malignant-276.jpg
# Moved: malignant-277.jpg
# Moved: malignant-278.jpg
# Moved: malignant-279.jpg
# Moved: malignant-280.jpg
# Moved: malignant-281.jpg
# Moved: malignant-282.jpg
# Moved: malignant-283.jpg
# Moved: malignant-284.jpg
# Moved: malignant-285.jpg
# Moved: malignant-286.jpg
# Moved: malignant-287.jpg
# Moved: malignant-288.jpg
# Moved: malignant-289.jpg
# Moved: malignant-290.jpg
# Moved: malignant-291.jpg
# Moved: malignant-292.jpg
# Moved: malignant-293.jpg
# Moved: malignant-294.jpg
# Moved: malignant-295.jpg
# Moved: malignant-296.jpg
# Moved: malignant-297.jpg
# Moved: malignant-298.jpg
# Moved: malignant-299.jpg
# Moved: malignant-300.jpg
# Moved: labels_test.json

# %%
transform = transforms.Compose([
    transforms.Resize(size=224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225]) # Imagenet standards
    ])
#data directory
data_dir = "/content/drive/MyDrive/kaggle/c_data/"
with open('/content/drive/MyDrive/kaggle/c_data/labels.json') as f:
    targets = json.load(f)

data_dir_test = "/content/drive/MyDrive/kaggle/c_data_test/"
with open('/content/drive/MyDrive/kaggle/c_data_test/labels_test.json') as f:
    targets_test = json.load(f)

# %%
train_data = SkinCancerDataset(targets.items(), data_dir, transform)
test_data = SkinCancerDataset(targets_test.items(), data_dir_test, transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)

# Randomize order
num_train_test = len(test_data)
indices_test = list(range(num_train_test))
np.random.shuffle(indices_test)

# %%
# Slicing Train/Valid in 80/20 ratio
split = int(np.floor(valid_size * num_train))
test_idx, valid_idx, train_idx = indices_test[:], indices[:split], indices[split:]

# %%
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)
test_sampler = SubsetRandomSampler(test_idx)

# %%
# prepare data loaders (combine dataset and sampler)
train_loader = DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = DataLoader(train_data, batch_size=batch_size,
    sampler=valid_sampler, num_workers=num_workers)
test_loader = DataLoader(test_data, batch_size=batch_size,
    sampler=test_sampler, num_workers=num_workers)

# %%
import numpy as np
import torch
import torch.optim as optim
import torch.nn as nn

# check if CUDA is available. If so, device will be gpu
device = "cuda" if torch.cuda.is_available() else "cpu"

vgg16.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=512, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
# specify loss function
criterion = nn.CrossEntropyLoss()
# specify optimize
optimizer = optim.Adam(params=vgg16.classifier.parameters(), lr = 0.001)

# %%
# Freeze training for all "features" layers
for param in vgg16.features.parameters():
    param.requires_grad = False

# %%
def accuracy_fn(y_true, y_pred):
  # correct = torch.eq(y_true, y_pred).sum().item()
  # acc = (correct/len(y_pred)) * 100
  # return acc

# %%
# Saving library
from pathlib import Path

# Create model directory path
MODEL_PATH = Path("/content/drive/MyDrive/kaggle/models/")
MODEL_PATH.mkdir(parents=True,
                 exist_ok=True)

# Create model save path
MODEL_NAME = "vgg16_skin_cancer.pt"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# %%
from tqdm.auto import tqdm
from timeit import default_timer as timer
# number of epochs to train the model

start = timer()

n_epochs = 10

valid_loss_min = np.Inf # track change in validation loss(starting with infinity)
train_loss_min = np.Inf

for epoch in tqdm(range(1, n_epochs+1)):

  # keep track of training and validation loss
  train_loss = 0.0
  valid_loss = 0.0

  ### Train the model
  vgg16.train()
  for data, target in train_loader:
    # move tensors to GPU if CUDA is available
    data, target = data.to(device), target.to(device)
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg16(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # clear the gradients of all optimized variables
    optimizer.zero_grad()
    # backward pass: compute gradient of the loss with respect to model parameters
    loss.backward()
    # perform a single optimization step (parameter update)
    optimizer.step()
    # update training loss
    train_loss += loss.item()*data.size(0)

  ### Validation
  vgg16.eval()

  with torch.inference_mode():
    for data, target in valid_loader:
      # move tensors to GPU if CUDA is available
      data, target = data.to(device), target.to(device)
      # forward pass: compute predicted outputs by passing inputs to the model
      output = vgg16(data)
      # calculate the batch loss
      loss = criterion(output, target)
      # update average validation loss
      valid_loss += loss.item()*data.size(0)

  # calculate average losses
  train_loss = train_loss/len(train_loader.dataset)
  valid_loss = valid_loss/len(valid_loader.dataset)

  # print training/validation statistics
  print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
      epoch, train_loss, valid_loss))

  # save model if validation loss has decreased (this is done to make sure the model doesn't overfit on the training data and detect patterns that aren't there)
  if valid_loss <= valid_loss_min:
      print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
      valid_loss_min,
      valid_loss))
      # Save the model state dict
      torch.save(obj=vgg16.state_dict(), f=MODEL_SAVE_PATH)
      valid_loss_min = valid_loss

  # if train_loss <= train_loss_min:
  #     print('Training loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
  #     train_loss_min,
  #     train_loss))
  #     # Save the model state dict
  #     torch.save(obj=vgg16.state_dict(), f=MODEL_SAVE_PATH)
  #     train_loss_min = train_loss
  # torch.save(obj=vgg16.state_dict(), f=MODEL_SAVE_PATH)

end = timer()

print(f"Time to train: {end - start}")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 	Training Loss: 0.497714 	Validation Loss: 0.062430
# Validation loss decreased (inf --> 0.062430).  Saving model ...
# Epoch: 2 	Training Loss: 0.265590 	Validation Loss: 0.059148
# Validation loss decreased (0.062430 --> 0.059148).  Saving model ...
# Epoch: 3 	Training Loss: 0.178262 	Validation Loss: 0.056004
# Validation loss decreased (0.059148 --> 0.056004).  Saving model ...
# Epoch: 4 	Training Loss: 0.116954 	Validation Loss: 0.085280
# Epoch: 5 	Training Loss: 0.099517 	Validation Loss: 0.153448
# Epoch: 6 	Training Loss: 0.108818 	Validation Loss: 0.076947
# Epoch: 7 	Training Loss: 0.094306 	Validation Loss: 0.233880
# Epoch: 8 	Training Loss: 0.083714 	Validation Loss: 0.136680
# Epoch: 9 	Training Loss: 0.058495 	Validation Loss: 0.172894
# Epoch: 10 	Training Loss: 0.040200 	Validation Loss: 0.135620
# Time to train: 1054.812142344

# %%
import numpy as np
import torch
import torch.nn as nn

## track test loss (Classification)
batch_size = 20

    ## if GPU is_available
#test_on_gpu = torch.cuda.is_available()
# test_on_gpu = False
# if not test_on_gpu:
#     print('CUDA is not available.  Testing on CPU ...')
# else:
#     print('CUDA is available.  Testing on GPU ...')

# Load model
vgg16.load_state_dict(torch.load(MODEL_SAVE_PATH))

    ##Model should be on GPU with dataset
# if test_on_gpu:
#     vgg16.cuda()

#same criterion as training
criterion = nn.CrossEntropyLoss()
number_of_classes = 2
class_correct = list(0. for i in range(number_of_classes))
class_total = list(0. for i in range(number_of_classes))

#Keeping track of test loss
test_loss = 0.0

vgg16.eval()
# iterate over test data
for data, target in test_loader:
    data, target = data.to(device), target.to(device)
    # move tensors to GPU if CUDA is available
    # if test_on_gpu:
    #     data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg16(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())
    print(correct)
    # calculate test accuracy for each object class
    for i in range(len(correct)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

## Test Error in each class
classes = ['Benign', 'Malignant']

for i in range(number_of_classes):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

#Overall Accuracy
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# [ True  True False False False  True  True  True  True  True  True  True
#   True  True False  True  True  True  True  True]
# [ True  True  True  True  True False  True  True  True  True  True  True
#  False  True  True  True  True  True  True  True]
# [ True  True False  True False  True  True  True  True False  True  True
#   True  True  True  True  True  True  True  True]
# [False  True  True  True  True  True  True  True  True False  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True False  True  True  True  True False  True False  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True False  True]
# [ True  True  True  True  True  True  True  True  True  True  True False
#   True  True  True False  True False  True False]
# [ True False  True False False  True  True  True  True  True  True  True
#  False  True  True  True  True False  True  True]
# [ True  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True False  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [False  True False  True False  True  True  True  True  True False  True
#   True False  True False  True  True False  True]
# [ True  True  True  True  True  True  True False  True  True  True  True
#   True  True  True  True False  True  True  True]
# [ True  True False  True  True  True  True  True  True  True  True False
#   True  True  True  True  True  True  True  True]
# [ True False  True  True  True  True  True  True False  True  True False
#  False  True False  True False False  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False  True  True]
# [ True  True  True  True False False  True  True  True  True  True  True
#   True  True  True  True False  True  True  True]
# [False  True  True  True  True  True  True  True  True  True  True  True
#  False  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True False  True  True  True False  True
#   True  True  True False False  True  True  True]
# [ True  True  True  True  True  True False  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True False  True  True  True  True  True
#   True False  True  True  True  True  True  True]
# [ True  True False  True  True  True False False  True  True  True  True
#  False  True  True  True False  True  True False]
# [ True  True  True  True  True  True  True  True  True  True False  True
#   True  True False  True  True  True False  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#  False  True  True False  True  True  True  True]
# [ True  True  True False False False False  True  True False  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False  True  True  True False  True  True]
# [ True  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False  True  True]
# [ True  True False  True False  True  True  True  True  True  True  True
#  False  True  True  True  True  True  True  True]
# [ True False False  True  True  True False  True  True  True  True  True
#   True  True  True  True  True False  True  True]
# [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True False False  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True False  True  True  True  True]
# [ True  True  True False  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True False  True  True  True  True  True False  True False  True  True
#   True  True  True  True  True  True  True  True]
# Test Loss: 0.314712
#
# Test Accuracy of Benign: 87% (316/360)
# Test Accuracy of Malignant: 82% (248/300)
#
# Test Accuracy (Overall): 85% (564/660)

# %%
# Import tqdm.auto
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
vgg16.eval()
with torch.inference_mode():
  for X, y in tqdm(test_loader, desc="Making predictions..."):
    # Send the data and targets to target device
    X, y = X.to(device), y.to(device)
    # Do the forward pass
    y_logit = vgg16(X)
    # Turn predictions from logits -> prediction probabilities -> prediction labels
    y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
    y_preds.append(y_pred.cpu())

# Contcatenate list of predictions into tensor
# print(y_preds)
y_pred_tensor = torch.cat(y_preds)
y_pred_tensor[:10]

# %%
# See if require packages are installed and if not, install them...
try:
  import torchmetrics, mlxtend
  print(f"mlxtend version: {mlxtend.__version__}")
  assert int(mlxtend.__version__.splot(".")[1]) >= 19, "mlxtend version should be 0.19.0 or higher"
except:
  # !pip install -q torchmetrics -U
  import torchmetrics, mlxtend

# %%
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

confmat = ConfusionMatrix(num_classes=len(test_loader), task='multiclass')
confmat_tensor = confmat(preds=y_pred_tensor, target=torch.tensor([target for data, target in test_loader]))
print(y_pred_tensor[:10])
print(test_data.targets[:10])

# 3. Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(),    # matplotlib like numpy
    class_names=class_names,
    figsize=(10, 7)
    )

# %%
MODEL_NAME_2 = "vgg16_model.pt"
MODEL_SAVE_PATH_2 = MODEL_PATH / MODEL_NAME_2
torch.save(vgg16, MODEL_SAVE_PATH_2)

# %%
import torch
from torch.utils.mobile_optimizer import optimize_for_mobile

LIGHT_MODEL_NAME = "torchscript_small.pt"
LIGHT_MODEL_SAVE_PATH = MODEL_PATH / LIGHT_MODEL_NAME

model = torch.load(MODEL_SAVE_PATH_2, map_location="cpu")
model.eval()
example = torch.rand(1, 3, 224, 224)
traced_script_module = torch.jit.trace(model, example)
optimized_traced_model = optimize_for_mobile(traced_script_module)
optimized_traced_model._save_for_lite_interpreter(LIGHT_MODEL_NAME)

# %%
import os
import shutil

source_folder = r"/content/"
destination_folder = r"/content/drive/MyDrive/kaggle/models/"

file_name = "torchscript_small.pt"
# construct full file path
source = source_folder + file_name
destination = destination_folder + file_name
# move only files
if os.path.isfile(source):
    shutil.move(source, destination)
    print('Moved:', file_name)
# Out:
# Moved: torchscript_small.pt

# %%
import torch
import torchvision
vgg16 = torch.load("/content/drive/MyDrive/kaggle/models/vgg16_model.pt", map_location=torch.device('cpu'))
vgg16.eval()
example = torch.rand(1, 3, 224, 224)
traced_script_module = torch.jit.trace(vgg16, example)
traced_script_module.save("/content/drive/MyDrive/kaggle/models/vgg_16_torchscript.pt")

# %%
import numpy as np
import torch
import torch.nn as nn

## track test loss (Classification)
batch_size = 20

    ## if GPU is_available
#test_on_gpu = torch.cuda.is_available()
test_on_gpu = False
# if not test_on_gpu:
#     print('CUDA is not available.  Testing on CPU ...')
# else:
#     print('CUDA is available.  Testing on GPU ...')

# Load model
# vgg16.load_state_dict(torch.load(MODEL_SAVE_PATH))

    ##Model should be on GPU with dataset
# if test_on_gpu:
#     vgg16.cuda()

#same criterion as training
criterion = nn.CrossEntropyLoss()
number_of_classes = 2
class_correct = list(0. for i in range(number_of_classes))
class_total = list(0. for i in range(number_of_classes))

#Keeping track of test loss
test_loss = 0.0

vgg16.eval()
# iterate over test data
for data, target in test_loader:
    data, target = data.to(device), target.to(device)
    # move tensors to GPU if CUDA is available
    # if test_on_gpu:
    #     data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = vgg16(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())
    print(correct)
    # calculate test accuracy for each object class
    for i in range(len(correct)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

## Test Error in each class
classes = ['Benign', 'Malignant']

for i in range(number_of_classes):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

#Overall Accuracy
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# [False  True  True  True  True  True  True  True  True  True False  True
#   True  True False  True  True False  True False]
# [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True False  True  True False  True  True  True  True  True
#   True  True  True  True  True False  True  True]
# [ True  True  True  True False  True  True False  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True False  True  True  True  True  True  True
#   True  True  True False  True False  True  True]
# [ True  True  True  True  True  True  True  True  True False  True False
#  False  True  True  True  True  True False  True]
# [ True False  True  True  True  True  True  True  True False  True False
#  False  True  True  True  True  True False  True]
# [ True  True  True  True False False  True  True  True False False  True
#  False  True  True  True  True  True  True  True]
# [ True False  True  True  True  True  True  True False False  True  True
#   True  True  True  True  True  True False False]
# [ True  True False  True  True  True  True  True False  True  True  True
#   True  True  True  True  True False  True  True]
# [ True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True False  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True False  True  True False  True  True  True False  True False
#   True  True  True  True  True  True  True  True]
# [False  True  True  True  True  True  True False  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [False  True  True False  True  True  True False  True  True  True  True
#   True  True  True False  True  True  True  True]
# [ True  True  True  True  True  True False False  True  True  True  True
#   True False  True  True  True  True  True  True]
# [ True  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True False False  True  True  True  True  True  True  True
#   True  True  True  True  True  True False  True]
# [ True  True False  True  True  True  True  True  True False  True  True
#   True  True  True False  True  True  True  True]
# [False  True  True  True  True  True  True  True  True  True  True  True
#  False  True False False  True  True  True  True]
# [ True  True  True  True  True  True  True False  True  True  True  True
#   True  True  True  True  True False  True  True]
# [False False  True  True  True  True False  True  True  True False  True
#  False  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True False False
#   True  True  True False  True  True  True  True]
# [ True  True False  True  True  True  True  True  True  True  True  True
#   True False  True  True  True  True  True  True]
# [ True  True  True False  True  True  True False False  True  True  True
#   True False  True  True False False  True  True]
# [ True  True  True  True  True  True  True  True  True False  True False
#   True  True False  True  True  True  True  True]
# [ True  True  True False  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [False  True  True False  True  True  True False False  True  True  True
#   True False  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True False
#   True  True  True False False  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False  True  True False  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True False  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False  True  True  True  True  True  True]
# Test Loss: 0.314712
#
# Test Accuracy of Benign: 87% (316/360)
# Test Accuracy of Malignant: 82% (248/300)
#
# Test Accuracy (Overall): 85% (564/660)

# %%
pip install onnx
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx) (1.23.5)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (3.20.3)

# %%
import torch
import onnx
import torchvision

# Load  PyTorch model
vgg16 = torch.load("/content/drive/MyDrive/kaggle/models/vgg16_model.pt", map_location=torch.device('cpu'))

# Set  input shape of the model
input_shape = (1, 3, 224, 224)

# Export  PyTorch model to ONNX format
torch.onnx.export(vgg16, torch.randn(input_shape), 'vgg16.onnx', opset_version=11)

# %%
# !pip install onnx-tf
import onnx_tf

# Load  ONNX model
onnx_model = onnx.load('vgg16.onnx')

# Convert ONNX model to TensorFlow format
tf_model = onnx_tf.backend.prepare(onnx_model)
# Export  TensorFlow  model
tf_model.export_graph("vgg16.tf")
# Out:
# Collecting onnx-tf
#   Downloading onnx_tf-1.10.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.1/226.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: onnx>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from onnx-tf) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from onnx-tf) (6.0.1)
# Collecting tensorflow-addons (from onnx-tf)
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx>=1.10.2->onnx-tf) (1.23.5)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.10.2->onnx-tf) (3.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->onnx-tf) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->onnx-tf)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons, onnx-tf
# Successfully installed onnx-tf-1.10.0 tensorflow-addons-0.23.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# WARNING:absl:`input.1` is not a valid tf.function parameter name. Sanitizing to `input_1`.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d7bff9584466> in <cell line: 10>()
#       8 tf_model = onnx_tf.backend.prepare(onnx_model)
#       9 # Export  TensorFlow  model
# ---> 10 tf_model.export_graph("vgg16.tf")
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend_rep.py in export_graph(self, path)
#     141         self.tf_module,
#     142         path,
# --> 143         signatures=self.tf_module.__call__.get_concrete_function(
#     144             **self.signatures))
#     145     self.tf_module.is_export = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1225   def get_concrete_function(self, *args, **kwargs):
#    1226     # Implements PolymorphicFunction.get_concrete_function.
# -> 1227     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195       if self._variable_creation_config is None:
#    1196         initializers = []
# -> 1197         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198         self._initialize_uninitialized_variables(initializers)
#    1199
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     693     )
#     694     # Force the definition of the function for these arguments
# --> 695     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696         args, kwds, self._variable_creation_config
#     697     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in bound_method_wrapper(*args, **kwargs)
#    1693     # However, the replacer is still responsible for attaching self properly.
#    1694     # TODO(mdan): Is it possible to do it here instead?
# -> 1695     return wrapped_fn(*args, **kwargs)
#    1696
#    1697   weak_bound_method_wrapper = weakref.ref(bound_method_wrapper)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
# ---> 52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#      54         raise
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend_tf_module.py in tf____call__(self, **kwargs)
#      28                 output_ops = ag__.Undefined('output_ops')
#      29                 curr_node_output_map = ag__.Undefined('curr_node_output_map')
# ---> 30                 ag__.for_stmt(ag__.ld(self).graph_def.node, None, loop_body, get_state, set_state, (), {'iterate_names': 'node'})
#      31                 outputs = ag__.converted_call(ag__.ld(dict), (), None, fscope)
#      32
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in for_stmt(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     447       for_fn = _tf_distributed_iterable_for_stmt
#     448
# --> 449   for_fn(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#     450
#     451
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in _py_for_stmt(***failed resolving arguments***)
#     498   else:
#     499     for target in iter_:
# --> 500       body(target)
#     501
#     502
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in protected_body(protected_iter)
#     464     original_body = body
#     465     def protected_body(protected_iter):
# --> 466       original_body(protected_iter)
#     467       after_iteration()
#     468       before_iteration()
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend_tf_module.py in loop_body(itr)
#      21                     node = itr
#      22                     onnx_node = ag__.converted_call(ag__.ld(OnnxNode), (ag__.ld(node),), None, fscope)
# ---> 23                     output_ops = ag__.converted_call(ag__.ld(self).backend._onnx_node_to_tensorflow_op, (ag__.ld(onnx_node), ag__.ld(tensor_dict), ag__.ld(self).handlers), dict(opset=ag__.ld(self).opset, strict=ag__.ld(self).strict), fscope)
#      24                     curr_node_output_map = ag__.converted_call(ag__.ld(dict), (ag__.converted_call(ag__.ld(zip), (ag__.ld(onnx_node).outputs, ag__.ld(output_ops)), None, fscope),), None, fscope)
#      25                     ag__.converted_call(ag__.ld(tensor_dict).update, (ag__.ld(curr_node_output_map),), None, fscope)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend.py in tf___onnx_node_to_tensorflow_op(cls, node, tensor_dict, handlers, opset, strict)
#      60                     pass
#      61                 handler = ag__.Undefined('handler')
# ---> 62                 ag__.if_stmt(ag__.ld(handlers), if_body_1, else_body_1, get_state_1, set_state_1, ('do_return', 'retval_'), 2)
#      63
#      64                 def get_state_2():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1215     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216   else:
# -> 1217     _py_if_stmt(cond, body, orelse)
#    1218
#    1219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1268 def _py_if_stmt(cond, body, orelse):
#    1269   """Overload of if_stmt that executes a Python if statement."""
# -> 1270   return body() if cond else orelse()
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend.py in if_body_1()
#      54                         nonlocal retval_, do_return
#      55                         pass
# ---> 56                     ag__.if_stmt(ag__.ld(handler), if_body, else_body, get_state, set_state, ('do_return', 'retval_'), 2)
#      57
#      58                 def else_body_1():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1215     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216   else:
# -> 1217     _py_if_stmt(cond, body, orelse)
#    1218
#    1219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1268 def _py_if_stmt(cond, body, orelse):
#    1269   """Overload of if_stmt that executes a Python if statement."""
# -> 1270   return body() if cond else orelse()
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/backend.py in if_body()
#      46                         try:
#      47                             do_return = True
# ---> 48                             retval_ = ag__.converted_call(ag__.ld(handler).handle, (ag__.ld(node),), dict(tensor_dict=ag__.ld(tensor_dict), strict=ag__.ld(strict)), fscope)
#      49                         except:
#      50                             do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/handler.py in tf__handle(cls, node, **kwargs)
#      39                     nonlocal retval_, do_return
#      40                     raise ag__.converted_call(ag__.ld(BackendIsNotSupposedToImplementIt), (ag__.converted_call('{} version {} is not implemented.'.format, (ag__.ld(node).op_type, ag__.ld(cls).SINCE_VERSION), None, fscope),), None, fscope)
# ---> 41                 ag__.if_stmt(ag__.ld(ver_handle), if_body, else_body, get_state, set_state, ('do_return', 'retval_'), 2)
#      42                 return fscope.ret(retval_, do_return)
#      43         return tf__handle
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1215     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216   else:
# -> 1217     _py_if_stmt(cond, body, orelse)
#    1218
#    1219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py in _py_if_stmt(cond, body, orelse)
#    1268 def _py_if_stmt(cond, body, orelse):
#    1269   """Overload of if_stmt that executes a Python if statement."""
# -> 1270   return body() if cond else orelse()
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/handler.py in if_body()
#      31                     try:
#      32                         do_return = True
# ---> 33                         retval_ = ag__.converted_call(ag__.ld(ver_handle), (ag__.ld(node),), dict(**ag__.ld(kwargs)), fscope)
#      34                     except:
#      35                         do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/backend/conv.py in tf__version(cls, node, **kwargs)
#      10                 try:
#      11                     do_return = True
# ---> 12                     retval_ = ag__.converted_call(ag__.ld(cls).conv, (ag__.ld(node), ag__.ld(kwargs)['tensor_dict']), None, fscope)
#      13                 except:
#      14                     do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439         result = converted_f(*effective_args, **kwargs)
#     440       else:
# --> 441         result = converted_f(*effective_args)
#     442     except Exception as e:
#     443       _attach_error_metadata(e, converted_f)
#
# /usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/backend/conv_mixin.py in tf__conv(cls, node, input_dict, transpose)
#      17                 do_return = False
#      18                 retval_ = ag__.UndefinedReturnValue()
# ---> 19                 x = ag__.ld(input_dict)[ag__.ld(node).inputs[0]]
#      20                 x_rank = ag__.converted_call(ag__.ld(len), (ag__.converted_call(ag__.ld(x).get_shape, (), None, fscope),), None, fscope)
#      21                 x_shape = ag__.converted_call(ag__.ld(tf_shape), (ag__.ld(x), ag__.ld(tf).int32), None, fscope)
#
# KeyError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/onnx_tf/backend_tf_module.py", line 99, in __call__  *
#         output_ops = self.backend._onnx_node_to_tensorflow_op(onnx_node,
#     File "/usr/local/lib/python3.10/dist-packages/onnx_tf/backend.py", line 347, in _onnx_node_to_tensorflow_op  *
#         return handler.handle(node, tensor_dict=tensor_dict, strict=strict)
#     File "/usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/handler.py", line 59, in handle  *
#         return ver_handle(node, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/backend/conv.py", line 15, in version_11  *
#         return cls.conv(node, kwargs["tensor_dict"])
#     File "/usr/local/lib/python3.10/dist-packages/onnx_tf/handlers/backend/conv_mixin.py", line 29, in conv  *
#         x = input_dict[node.inputs[0]]
#
#     KeyError: 'input.1'

# %%
import onnx
from onnx import helper

onnx_model = onnx.load(onnx_model_path)

# Define a mapping from old names to new names
name_map = {"input.1": "input_1"}

# Initialize a list to hold the new inputs
new_inputs = []

# Iterate over the inputs and change their names if needed
for inp in onnx_model.graph.input:
    if inp.name in name_map:
        # Create a new ValueInfoProto with the new name
        new_inp = helper.make_tensor_value_info(name_map[inp.name],
                                                inp.type.tensor_type.elem_type,
                                                [dim.dim_value for dim in inp.type.tensor_type.shape.dim])
        new_inputs.append(new_inp)
    else:
        new_inputs.append(inp)

# Clear the old inputs and add the new ones
onnx_model.graph.ClearField("input")
onnx_model.graph.input.extend(new_inputs)

# Go through all nodes in the model and replace the old input name with the new one
for node in onnx_model.graph.node:
    for i, input_name in enumerate(node.input):
        if input_name in name_map:
            node.input[i] = name_map[input_name]

# Save the renamed ONNX model
onnx.save(onnx_model, 'resnet50-new.onnx')

# %%
import torch
import onnx
import tensorflow as tf
import onnx_tf
# from torchvision.models import resnet50

# Load the PyTorch ResNet50 model
vgg16 = torch.load("/content/drive/MyDrive/kaggle/models/vgg16_model.pt", map_location=torch.device('cpu'))
vgg16.eval()

# Export the PyTorch model to ONNX format
input_shape = (1, 3, 224, 224)
dummy_input = torch.randn(input_shape)
onnx_model_path = 'vgg16.onnx'
torch.onnx.export(vgg16, dummy_input, onnx_model_path, verbose=False)

# # Load the ONNX model
# onnx_model = onnx.load(onnx_model_path)

# # Convert the ONNX model to TensorFlow format
# tf_model_path = 'vgg16.pb'
# tf_rep = onnx_tf.backend.prepare(onnx_model)
# tf_rep.export_graph(tf_model_path)


# # Convert the TensorFlow model to TensorFlow Lite format
# converter = tf.compat.v1.lite.TFLiteConverter.from_saved_model(tf_model_path)
# tflite_model = converter.convert()

# # Save the TensorFlow Lite model to a file
# with open('vgg16.tflite', 'wb') as f:
#     f.write(tflite_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
import onnx
from onnx import helper

onnx_model = onnx.load(onnx_model_path)

# Define a mapping from old names to new names
name_map = {"input.1": "input_1"}

# Initialize a list to hold the new inputs
new_inputs = []

# Iterate over the inputs and change their names if needed
for inp in onnx_model.graph.input:
    if inp.name in name_map:
        # Create a new ValueInfoProto with the new name
        new_inp = helper.make_tensor_value_info(name_map[inp.name],
                                                inp.type.tensor_type.elem_type,
                                                [dim.dim_value for dim in inp.type.tensor_type.shape.dim])
        new_inputs.append(new_inp)
    else:
        new_inputs.append(inp)

# Clear the old inputs and add the new ones
onnx_model.graph.ClearField("input")
onnx_model.graph.input.extend(new_inputs)

# Go through all nodes in the model and replace the old input name with the new one
for node in onnx_model.graph.node:
    for i, input_name in enumerate(node.input):
        if input_name in name_map:
            node.input[i] = name_map[input_name]

# Save the renamed ONNX model
onnx.save(onnx_model, 'vgg16-new.onnx')

# %%
# Load the ONNX model
onnx_model_path_new = "vgg16-new.onnx"
onnx_model = onnx.load(onnx_model_path_new)

# Convert the ONNX model to TensorFlow format
tf_model_path = 'vgg16.tf'
tf_rep = onnx_tf.backend.prepare(onnx_model)
tf_rep.export_graph(tf_model_path)


converter = tf.lite.TFLiteConverter.from_saved_model(tf_model_path)
tflite_model = converter.convert()
open('vgg16.tflite', 'wb').write(tflite_model)
# Out:
# INFO:absl:Function `__call__` contains input name(s) x, y with unsupported characters which will be renamed to transpose_53_x, mul_3_y in the SavedModel.
# INFO:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:absl:Writing fingerprint to vgg16.tf/fingerprint.pb
# 478324404

# %%
import os
import shutil

source_folder = r"/content/"
destination_folder = r"/content/drive/MyDrive/kaggle/models/"

file_name = "resnet18.tflite"
# construct full file path
source = source_folder + file_name
new_file_name = "vgg16.tflite"
destination = destination_folder + new_file_name
# move only files
if os.path.isfile(source):
    shutil.move(source, destination)
    print('Moved:', file_name)
# Out:
# Moved: resnet18.tflite
